# %% [markdown]
# # Es 1a - Conceptual Similarity

# %% [markdown]
# In questo esercizio andiamo ad esplorare varie tecniche per calcolare la similarità semantica tra
# due parole. Per farlo utilizzeremo il dataset WordSim353.csv, che contiene una serie di coppie di
#  parole e il loro punteggio di similarità. Il punteggio è un valore reale compreso tra 0 e 10.
#
# Le misure di similarità che utilizzeremo sono:
#
# - Wu and Palmer
# - Shortest Path
# - Leakcock & Chodorow

# %% [markdown]
# ### Imports

# %%
from nltk.corpus import stopwords
from collections import Counter
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet as wn
import random
import numpy as np
from iteration_utilities import deepflatten
from scipy import stats

# %% [markdown]
# ### Data preparation

# %%
def extract_triple(path):
    '''
    Read a file and return the first 2 word in each row, as a tuple.
    '''
    tuple_list = []
    with open (path, 'r') as f:
        for row in f:
            # Remove \n
            row = row.strip()
            # Organize in a triple the VALUES
            tuple_list.append(tuple(row.split(",")[:3]))
            
        # Remove first value of the tuple
        tuple_list.pop(0)
    f.close()
    return tuple_list

# %%
VALUES = extract_triple('../data/WordSim353.csv')

# %% [markdown]
# ## Conceptual similarity methods

# %% [markdown]
# ### WordNet Methods

# %% [markdown]
# Nota: Normalizziamo tutti i valori nell'intervallo [0;10] per facilitare il confronto
# con il file di partenza

# %%
def max_similarity(syns1, syns2, sim_fuct):
    '''
    The method comprare all the synsets of the 2 term and return the
    synsets with the highest similarity with the relative score.
    
    Args:
        syns1: list of synsets of the first term
        syns2: list of synsets of the second term
    Returns:
        the higher value for similarity and the relative synsets
    '''
    sim_max = ("", "", -100)
    
    for syn1 in syns1:
        for syn2 in syns2:
            sim = sim_fuct(syn1, syn2)
            if sim >= sim_max[2]:
                sim_max = (syn1, syn2, sim)      
                        
    return sim_max

def sim_res_list(sim_funct):
    res = []
    VALUES = extract_triple('../data/WordSim353.csv')
    
    for val in VALUES:
        syns1 = get_synsets(val[0])
        syns2 = get_synsets(val[1])
    
        if(syns1 is not None and syns2 is not None):
            sim = max_similarity(syns1, syns2, sim_funct)
            res.append(sim[2])
        else:
            res.append(0)
            
    return res

def print_result(sim_funct):
    for val in VALUES:
        syns1 = get_synsets(val[0])
        syns2 = get_synsets(val[1])
    
        if(syns1 is not None and syns2 is not None):
            sim = max_similarity(syns1, syns2, sim_funct)
            s = sim[2]
            so = val[2]
            diff = abs(round((s - float(so)), 2))
            
            print(f'{sim_funct.__name__} = {s}  \tgiven: {so} \tDiffernce --> {diff}')

def get_synsets(term):
    '''
    Retrurn the synsets of a term.
    '''
    if(len(wn.synsets(term)) > 0):
        return wn.synsets(term)
    return None
    
def lch(syn1, syn2): #? WordNet function
    '''
    Return the lowest common hypernyms of two synsets.
    '''
    if(syn1 is None or syn2 is None):
        return None
    return syn1.lowest_common_hypernyms(syn2)

def lowest_common_subsumer(synset1, synset2): #? My function that simulate the WordNet's function
    '''
    Args:
        synset1: first synset to take LCS from
        synset2: second synset to take LCS from
    Returns:
        the first common LCS
    '''
    if synset2 == synset1:
        return synset2

    commonsArr = []
    for hyper1 in synset1.hypernym_paths():
        for hyper2 in synset2.hypernym_paths():
            zipped = list(zip(hyper1, hyper2))  # merges 2 list in one list of tuples
            common = None
            for i in range(len(zipped)):
                if(zipped[i][0] != zipped[i][1]):
                    break
                common = (zipped[i][0], i)

            if common is not None and common not in commonsArr:
                commonsArr.append(common)
    
    if len(commonsArr) <= 0:
        return None

    commonsArr.sort(key=lambda x: x[1], reverse=True)
    return commonsArr[0][0]

def wu_pal_sim(syn1, syn2): #? WordNet function
    '''
    Return the Wu-Palmer similarity of two synsets.
    '''
    if(syn1 is None or syn2 is None):
        return 0
    return round(syn1.wup_similarity(syn2) * 10, 2)

def my_wu_pal_sim(syn1, syn2): #? My function that simulate the WordNet's function
    '''
    Implementation of Wu and Palm similarity metrics
    '''
    lcs = (lowest_common_subsumer(syn1, syn2))
    if lcs is None:
        return 0

    depth_lcs = depth_path(lcs, lcs)
    depth_s1 = depth_path(syn1, lcs)
    depth_s2 = depth_path(syn2, lcs)

    result = (2 * depth_lcs) / (depth_s1 + depth_s2)
    return round(result * 10, 2)

def depth_path(synset, lcs):
    """It measures the distance (depth) between the given Synset and the WordNet's root.
    Args:
        synset: synset to reach from the root
        lcs: Lowest Common Subsumer - the first common sense or most specific ancestor node
    Returns:
        the minimum path which contains LCS
    """
    paths = synset.hypernym_paths()
    paths = list(filter(lambda x: lcs in x, paths))  # all path containing LCS
    return min(len(path) for path in paths)

# %% [markdown]
# ## Wu and Palmer

# %% [markdown]
# ### Print the result

# %%
print_result(my_wu_pal_sim)
# Out:
# my_wu_pal_sim = 9.23  	given: 6.77 	Differnce --> 2.46
# my_wu_pal_sim = 9.66  	given: 7.35 	Differnce --> 2.31
# my_wu_pal_sim = 10.0  	given: 10.00 	Differnce --> 0.0
# my_wu_pal_sim = 8.75  	given: 7.46 	Differnce --> 1.29
# my_wu_pal_sim = 8.24  	given: 7.62 	Differnce --> 0.62
# my_wu_pal_sim = 6.32  	given: 7.58 	Differnce --> 1.26
# my_wu_pal_sim = 7.27  	given: 5.77 	Differnce --> 1.5
# my_wu_pal_sim = 7.37  	given: 6.31 	Differnce --> 1.06
# my_wu_pal_sim = 1.67  	given: 7.50 	Differnce --> 5.83
# my_wu_pal_sim = 9.09  	given: 6.77 	Differnce --> 2.32
# my_wu_pal_sim = 8.24  	given: 7.42 	Differnce --> 0.82
# my_wu_pal_sim = 1.82  	given: 6.85 	Differnce --> 5.03
# my_wu_pal_sim = 7.5  	given: 6.19 	Differnce --> 1.31
# my_wu_pal_sim = 8.24  	given: 5.92 	Differnce --> 2.32
# my_wu_pal_sim = 8.24  	given: 7.00 	Differnce --> 1.24
# my_wu_pal_sim = 6.67  	given: 6.62 	Differnce --> 0.05
# my_wu_pal_sim = 5.33  	given: 6.81 	Differnce --> 1.48
# my_wu_pal_sim = 1.33  	given: 4.62 	Differnce --> 3.29
# my_wu_pal_sim = 1.33  	given: 5.81 	Differnce --> 4.48
# my_wu_pal_sim = 6.15  	given: 7.08 	Differnce --> 0.93
# my_wu_pal_sim = 5.56  	given: 8.08 	Differnce --> 2.52
# my_wu_pal_sim = 7.0  	given: 1.62 	Differnce --> 5.38
# my_wu_pal_sim = 7.37  	given: 1.31 	Differnce --> 6.06
# my_wu_pal_sim = 8.15  	given: 0.92 	Differnce --> 7.23
# my_wu_pal_sim = 6.25  	given: 1.81 	Differnce --> 4.44
# my_wu_pal_sim = 1.54  	given: 6.69 	Differnce --> 5.15
# my_wu_pal_sim = 2.86  	given: 3.73 	Differnce --> 0.87
# my_wu_pal_sim = 6.15  	given: 0.92 	Differnce --> 5.23
# my_wu_pal_sim = 8.0  	given: 7.46 	Differnce --> 0.54
# my_wu_pal_sim = 5.71  	given: 8.12 	Differnce --> 2.41
# my_wu_pal_sim = 10.0  	given: 7.73 	Differnce --> 2.27
# my_wu_pal_sim = 8.75  	given: 9.15 	Differnce --> 0.4
# my_wu_pal_sim = 5.0  	given: 0.31 	Differnce --> 4.69
# my_wu_pal_sim = 5.71  	given: 0.23 	Differnce --> 5.48
# my_wu_pal_sim = 10.0  	given: 8.58 	Differnce --> 1.42
# my_wu_pal_sim = 9.09  	given: 5.92 	Differnce --> 3.17
# my_wu_pal_sim = 7.5  	given: 6.69 	Differnce --> 0.81
# my_wu_pal_sim = 7.0  	given: 8.46 	Differnce --> 1.46
# my_wu_pal_sim = 2.73  	given: 7.65 	Differnce --> 4.92
# my_wu_pal_sim = 3.08  	given: 1.62 	Differnce --> 1.46
# my_wu_pal_sim = 8.57  	given: 9.44 	Differnce --> 0.87
# my_wu_pal_sim = 9.52  	given: 9.03 	Differnce --> 0.49
# my_wu_pal_sim = 9.0  	given: 6.81 	Differnce --> 2.19
# my_wu_pal_sim = 7.62  	given: 6.63 	Differnce --> 0.99
# my_wu_pal_sim = 6.0  	given: 7.56 	Differnce --> 1.56
# my_wu_pal_sim = 1.43  	given: 6.73 	Differnce --> 5.3
# my_wu_pal_sim = 6.15  	given: 7.65 	Differnce --> 1.5
# my_wu_pal_sim = 8.0  	given: 2.50 	Differnce --> 5.5
# my_wu_pal_sim = 1.67  	given: 8.38 	Differnce --> 6.71
# my_wu_pal_sim = 5.33  	given: 7.38 	Differnce --> 2.05
# my_wu_pal_sim = 3.64  	given: 6.19 	Differnce --> 2.55
# my_wu_pal_sim = 4.44  	given: 6.73 	Differnce --> 2.29
# my_wu_pal_sim = 6.25  	given: 7.92 	Differnce --> 1.67
# my_wu_pal_sim = 2.22  	given: 8.12 	Differnce --> 5.9
# my_wu_pal_sim = 9.0  	given: 7.35 	Differnce --> 1.65
# my_wu_pal_sim = 4.44  	given: 4.88 	Differnce --> 0.44
# my_wu_pal_sim = 6.67  	given: 5.54 	Differnce --> 1.13
# my_wu_pal_sim = 8.89  	given: 8.46 	Differnce --> 0.43
# my_wu_pal_sim = 8.89  	given: 8.13 	Differnce --> 0.76
# my_wu_pal_sim = 2.86  	given: 3.04 	Differnce --> 0.18
# my_wu_pal_sim = 4.62  	given: 1.31 	Differnce --> 3.31
# my_wu_pal_sim = 5.0  	given: 5.96 	Differnce --> 0.96
# my_wu_pal_sim = 5.0  	given: 6.87 	Differnce --> 1.87
# my_wu_pal_sim = 7.5  	given: 7.85 	Differnce --> 0.35
# my_wu_pal_sim = 6.15  	given: 2.65 	Differnce --> 3.5
# my_wu_pal_sim = 10.0  	given: 8.94 	Differnce --> 1.06
# my_wu_pal_sim = 10.0  	given: 8.96 	Differnce --> 1.04
# my_wu_pal_sim = 9.52  	given: 9.29 	Differnce --> 0.23
# my_wu_pal_sim = 9.23  	given: 8.83 	Differnce --> 0.4
# my_wu_pal_sim = 9.09  	given: 9.10 	Differnce --> 0.01
# my_wu_pal_sim = 9.52  	given: 8.87 	Differnce --> 0.65
# my_wu_pal_sim = 10.0  	given: 9.02 	Differnce --> 0.98
# my_wu_pal_sim = 10.0  	given: 9.29 	Differnce --> 0.71
# my_wu_pal_sim = 5.26  	given: 8.79 	Differnce --> 3.53
# my_wu_pal_sim = 4.0  	given: 7.52 	Differnce --> 3.52
# my_wu_pal_sim = 9.52  	given: 7.10 	Differnce --> 2.42
# my_wu_pal_sim = 8.7  	given: 7.38 	Differnce --> 1.32
# my_wu_pal_sim = 9.33  	given: 6.46 	Differnce --> 2.87
# my_wu_pal_sim = 9.33  	given: 6.27 	Differnce --> 3.06
# my_wu_pal_sim = 7.5  	given: 2.69 	Differnce --> 4.81
# my_wu_pal_sim = 6.67  	given: 4.46 	Differnce --> 2.21
# my_wu_pal_sim = 1.05  	given: 5.85 	Differnce --> 4.8
# my_wu_pal_sim = 5.33  	given: 5.00 	Differnce --> 0.33
# my_wu_pal_sim = 4.29  	given: 2.08 	Differnce --> 2.21
# my_wu_pal_sim = 2.11  	given: 4.42 	Differnce --> 2.31
# my_wu_pal_sim = 6.67  	given: 4.38 	Differnce --> 2.29
# my_wu_pal_sim = 4.29  	given: 1.85 	Differnce --> 2.44
# my_wu_pal_sim = 6.0  	given: 3.08 	Differnce --> 2.92
# my_wu_pal_sim = 6.67  	given: 0.92 	Differnce --> 5.75
# my_wu_pal_sim = 5.45  	given: 3.15 	Differnce --> 2.3
# my_wu_pal_sim = 6.67  	given: 0.92 	Differnce --> 5.75
# my_wu_pal_sim = 3.75  	given: 0.54 	Differnce --> 3.21
# my_wu_pal_sim = 4.71  	given: 2.08 	Differnce --> 2.63
# my_wu_pal_sim = 2.67  	given: 0.54 	Differnce --> 2.13
# my_wu_pal_sim = 0.8  	given: 0.62 	Differnce --> 0.18
# my_wu_pal_sim = 7.78  	given: 8.42 	Differnce --> 0.64
# my_wu_pal_sim = 8.75  	given: 9.08 	Differnce --> 0.33
# my_wu_pal_sim = 9.33  	given: 9.04 	Differnce --> 0.29
# my_wu_pal_sim = 9.23  	given: 8.27 	Differnce --> 0.96
# my_wu_pal_sim = 8.33  	given: 7.57 	Differnce --> 0.76
# my_wu_pal_sim = 7.27  	given: 7.29 	Differnce --> 0.02
# my_wu_pal_sim = 5.71  	given: 8.50 	Differnce --> 2.79
# my_wu_pal_sim = 8.75  	given: 7.73 	Differnce --> 1.02
# my_wu_pal_sim = 2.86  	given: 6.88 	Differnce --> 4.02
# my_wu_pal_sim = 2.5  	given: 5.65 	Differnce --> 3.15
# my_wu_pal_sim = 3.33  	given: 3.31 	Differnce --> 0.02
# my_wu_pal_sim = 9.33  	given: 8.00 	Differnce --> 1.33
# my_wu_pal_sim = 9.29  	given: 8.00 	Differnce --> 1.29
# my_wu_pal_sim = 8.89  	given: 7.08 	Differnce --> 1.81
# my_wu_pal_sim = 8.0  	given: 6.85 	Differnce --> 1.15
# my_wu_pal_sim = 8.0  	given: 7.00 	Differnce --> 1.0
# my_wu_pal_sim = 8.57  	given: 4.77 	Differnce --> 3.8
# my_wu_pal_sim = 8.0  	given: 5.62 	Differnce --> 2.38
# my_wu_pal_sim = 5.33  	given: 5.87 	Differnce --> 0.54
# my_wu_pal_sim = 7.27  	given: 8.08 	Differnce --> 0.81
# my_wu_pal_sim = 2.5  	given: 7.00 	Differnce --> 4.5
# my_wu_pal_sim = 2.5  	given: 6.85 	Differnce --> 4.35
# my_wu_pal_sim = 3.53  	given: 7.42 	Differnce --> 3.89
# my_wu_pal_sim = 2.35  	given: 6.58 	Differnce --> 4.23
# my_wu_pal_sim = 3.33  	given: 6.42 	Differnce --> 3.09
# my_wu_pal_sim = 0.95  	given: 8.21 	Differnce --> 7.26
# my_wu_pal_sim = 5.88  	given: 7.69 	Differnce --> 1.81
# my_wu_pal_sim = 2.67  	given: 7.23 	Differnce --> 4.56
# my_wu_pal_sim = 9.41  	given: 6.71 	Differnce --> 2.7
# my_wu_pal_sim = 8.75  	given: 5.58 	Differnce --> 3.17
# my_wu_pal_sim = 6.15  	given: 7.48 	Differnce --> 1.33
# my_wu_pal_sim = 8.57  	given: 8.45 	Differnce --> 0.12
# my_wu_pal_sim = 7.69  	given: 8.06 	Differnce --> 0.37
# my_wu_pal_sim = 8.0  	given: 8.08 	Differnce --> 0.08
# my_wu_pal_sim = 8.0  	given: 8.02 	Differnce --> 0.02
# my_wu_pal_sim = 6.32  	given: 8.11 	Differnce --> 1.79
# my_wu_pal_sim = 5.33  	given: 7.92 	Differnce --> 2.59
# my_wu_pal_sim = 6.15  	given: 7.94 	Differnce --> 1.79
# my_wu_pal_sim = 9.23  	given: 5.85 	Differnce --> 3.38
# my_wu_pal_sim = 8.33  	given: 3.85 	Differnce --> 4.48
# my_wu_pal_sim = 7.27  	given: 2.81 	Differnce --> 4.46
# my_wu_pal_sim = 9.09  	given: 6.65 	Differnce --> 2.44
# my_wu_pal_sim = 8.0  	given: 2.50 	Differnce --> 5.5
# my_wu_pal_sim = 6.67  	given: 1.77 	Differnce --> 4.9
# my_wu_pal_sim = 6.15  	given: 6.04 	Differnce --> 0.11
# my_wu_pal_sim = 7.37  	given: 6.58 	Differnce --> 0.79
# my_wu_pal_sim = 8.89  	given: 6.85 	Differnce --> 2.04
# my_wu_pal_sim = 7.5  	given: 2.40 	Differnce --> 5.1
# my_wu_pal_sim = 7.69  	given: 2.92 	Differnce --> 4.77
# my_wu_pal_sim = 5.45  	given: 3.69 	Differnce --> 1.76
# my_wu_pal_sim = 2.86  	given: 2.15 	Differnce --> 0.71
# my_wu_pal_sim = 7.5  	given: 7.25 	Differnce --> 0.25
# my_wu_pal_sim = 6.67  	given: 5.00 	Differnce --> 1.67
# my_wu_pal_sim = 5.71  	given: 1.92 	Differnce --> 3.79
# my_wu_pal_sim = 7.06  	given: 5.90 	Differnce --> 1.16
# my_wu_pal_sim = 9.66  	given: 7.42 	Differnce --> 2.24
# my_wu_pal_sim = 3.33  	given: 7.27 	Differnce --> 3.94
# my_wu_pal_sim = 2.86  	given: 1.81 	Differnce --> 1.05
# my_wu_pal_sim = 1.33  	given: 5.06 	Differnce --> 3.73
# my_wu_pal_sim = 3.08  	given: 5.09 	Differnce --> 2.01
# my_wu_pal_sim = 4.0  	given: 6.78 	Differnce --> 2.78
# my_wu_pal_sim = 2.86  	given: 6.06 	Differnce --> 3.2
# my_wu_pal_sim = 2.5  	given: 6.94 	Differnce --> 4.44
# my_wu_pal_sim = 2.22  	given: 8.31 	Differnce --> 6.09
# my_wu_pal_sim = 8.24  	given: 4.59 	Differnce --> 3.65
# my_wu_pal_sim = 5.0  	given: 2.94 	Differnce --> 2.06
# my_wu_pal_sim = 4.71  	given: 5.63 	Differnce --> 0.92
# my_wu_pal_sim = 9.23  	given: 8.16 	Differnce --> 1.07
# my_wu_pal_sim = 3.53  	given: 7.53 	Differnce --> 4.0
# my_wu_pal_sim = 7.14  	given: 4.56 	Differnce --> 2.58
# my_wu_pal_sim = 4.0  	given: 6.34 	Differnce --> 2.34
# my_wu_pal_sim = 2.5  	given: 6.56 	Differnce --> 4.06
# my_wu_pal_sim = 7.5  	given: 2.38 	Differnce --> 5.12
# my_wu_pal_sim = 2.67  	given: 2.22 	Differnce --> 0.45
# my_wu_pal_sim = 8.0  	given: 8.66 	Differnce --> 0.66
# my_wu_pal_sim = 1.67  	given: 4.47 	Differnce --> 2.8
# my_wu_pal_sim = 6.15  	given: 5.34 	Differnce --> 0.81
# my_wu_pal_sim = 5.0  	given: 3.69 	Differnce --> 1.31
# my_wu_pal_sim = 2.35  	given: 3.00 	Differnce --> 0.65
# my_wu_pal_sim = 3.08  	given: 8.13 	Differnce --> 5.05
# my_wu_pal_sim = 9.09  	given: 6.31 	Differnce --> 2.78
# my_wu_pal_sim = 6.67  	given: 6.22 	Differnce --> 0.45
# my_wu_pal_sim = 7.69  	given: 6.50 	Differnce --> 1.19
# my_wu_pal_sim = 5.0  	given: 3.91 	Differnce --> 1.09
# my_wu_pal_sim = 1.54  	given: 2.56 	Differnce --> 1.02
# my_wu_pal_sim = 6.67  	given: 3.00 	Differnce --> 3.67
# my_wu_pal_sim = 2.67  	given: 5.63 	Differnce --> 2.96
# my_wu_pal_sim = 8.33  	given: 7.59 	Differnce --> 0.74
# my_wu_pal_sim = 3.64  	given: 3.16 	Differnce --> 0.48
# my_wu_pal_sim = 6.25  	given: 1.19 	Differnce --> 5.06
# my_wu_pal_sim = 5.33  	given: 3.31 	Differnce --> 2.02
# my_wu_pal_sim = 6.15  	given: 6.63 	Differnce --> 0.48
# my_wu_pal_sim = 3.08  	given: 4.75 	Differnce --> 1.67
# my_wu_pal_sim = 6.15  	given: 3.69 	Differnce --> 2.46
# my_wu_pal_sim = 3.08  	given: 4.25 	Differnce --> 1.17
# my_wu_pal_sim = 5.71  	given: 6.56 	Differnce --> 0.85
# my_wu_pal_sim = 7.14  	given: 4.25 	Differnce --> 2.89
# my_wu_pal_sim = 7.78  	given: 5.88 	Differnce --> 1.9
# my_wu_pal_sim = 6.25  	given: 5.94 	Differnce --> 0.31
# my_wu_pal_sim = 6.67  	given: 7.56 	Differnce --> 0.89
# my_wu_pal_sim = 3.08  	given: 2.75 	Differnce --> 0.33
# my_wu_pal_sim = 4.0  	given: 7.03 	Differnce --> 3.03
# my_wu_pal_sim = 5.33  	given: 5.47 	Differnce --> 0.14
# my_wu_pal_sim = 4.44  	given: 6.47 	Differnce --> 2.03
# my_wu_pal_sim = 7.69  	given: 7.91 	Differnce --> 0.22
# my_wu_pal_sim = 4.0  	given: 4.97 	Differnce --> 0.97
# my_wu_pal_sim = 2.67  	given: 5.00 	Differnce --> 2.33
# my_wu_pal_sim = 2.67  	given: 5.19 	Differnce --> 2.52
# my_wu_pal_sim = 6.25  	given: 7.03 	Differnce --> 0.78
# my_wu_pal_sim = 8.75  	given: 3.44 	Differnce --> 5.31
# my_wu_pal_sim = 5.56  	given: 2.31 	Differnce --> 3.25
# my_wu_pal_sim = 5.33  	given: 5.91 	Differnce --> 0.58
# my_wu_pal_sim = 2.5  	given: 7.38 	Differnce --> 4.88
# my_wu_pal_sim = 8.89  	given: 8.13 	Differnce --> 0.76
# my_wu_pal_sim = 2.67  	given: 4.63 	Differnce --> 1.96
# my_wu_pal_sim = 5.0  	given: 5.25 	Differnce --> 0.25
# my_wu_pal_sim = 2.86  	given: 5.03 	Differnce --> 2.17
# my_wu_pal_sim = 1.67  	given: 6.69 	Differnce --> 5.02
# my_wu_pal_sim = 8.57  	given: 7.88 	Differnce --> 0.69
# my_wu_pal_sim = 8.57  	given: 4.50 	Differnce --> 4.07
# my_wu_pal_sim = 4.55  	given: 4.75 	Differnce --> 0.2
# my_wu_pal_sim = 2.67  	given: 4.47 	Differnce --> 1.8
# my_wu_pal_sim = 1.33  	given: 3.25 	Differnce --> 1.92
# my_wu_pal_sim = 6.25  	given: 5.63 	Differnce --> 0.62
# my_wu_pal_sim = 7.14  	given: 3.69 	Differnce --> 3.45
# my_wu_pal_sim = 8.24  	given: 2.94 	Differnce --> 5.3
# my_wu_pal_sim = 2.5  	given: 5.28 	Differnce --> 2.78
# my_wu_pal_sim = 6.67  	given: 5.00 	Differnce --> 1.67
# my_wu_pal_sim = 5.0  	given: 6.44 	Differnce --> 1.44
# my_wu_pal_sim = 1.54  	given: 4.13 	Differnce --> 2.59
# my_wu_pal_sim = 3.08  	given: 4.75 	Differnce --> 1.67
# my_wu_pal_sim = 1.33  	given: 2.38 	Differnce --> 1.05
# my_wu_pal_sim = 5.88  	given: 4.94 	Differnce --> 0.94
# my_wu_pal_sim = 6.15  	given: 8.06 	Differnce --> 1.91
# my_wu_pal_sim = 7.27  	given: 5.31 	Differnce --> 1.96
# my_wu_pal_sim = 3.75  	given: 8.03 	Differnce --> 4.28
# my_wu_pal_sim = 1.33  	given: 5.94 	Differnce --> 4.61
# my_wu_pal_sim = 6.67  	given: 6.00 	Differnce --> 0.67
# my_wu_pal_sim = 6.67  	given: 5.41 	Differnce --> 1.26
# my_wu_pal_sim = 1.54  	given: 1.81 	Differnce --> 0.27
# my_wu_pal_sim = 9.47  	given: 8.97 	Differnce --> 0.5
# my_wu_pal_sim = 4.71  	given: 6.00 	Differnce --> 1.29
# my_wu_pal_sim = 8.42  	given: 6.72 	Differnce --> 1.7
# my_wu_pal_sim = 5.88  	given: 8.00 	Differnce --> 2.12
# my_wu_pal_sim = 6.25  	given: 4.81 	Differnce --> 1.44
# my_wu_pal_sim = 7.27  	given: 3.88 	Differnce --> 3.39
# my_wu_pal_sim = 4.0  	given: 5.16 	Differnce --> 1.16
# my_wu_pal_sim = 6.67  	given: 2.25 	Differnce --> 4.42
# my_wu_pal_sim = 6.15  	given: 6.44 	Differnce --> 0.29
# my_wu_pal_sim = 9.47  	given: 8.88 	Differnce --> 0.59
# my_wu_pal_sim = 6.67  	given: 6.88 	Differnce --> 0.21
# my_wu_pal_sim = 4.71  	given: 4.94 	Differnce --> 0.23
# my_wu_pal_sim = 3.16  	given: 2.56 	Differnce --> 0.6
# my_wu_pal_sim = 3.75  	given: 6.38 	Differnce --> 2.63
# my_wu_pal_sim = 9.0  	given: 7.81 	Differnce --> 1.19
# my_wu_pal_sim = 5.88  	given: 1.75 	Differnce --> 4.13
# my_wu_pal_sim = 7.69  	given: 4.25 	Differnce --> 3.44
# my_wu_pal_sim = 6.25  	given: 3.88 	Differnce --> 2.37
# my_wu_pal_sim = 5.0  	given: 2.88 	Differnce --> 2.12
# my_wu_pal_sim = 8.89  	given: 7.63 	Differnce --> 1.26
# my_wu_pal_sim = 2.86  	given: 6.48 	Differnce --> 3.62
# my_wu_pal_sim = 10.0  	given: 8.44 	Differnce --> 1.56
# my_wu_pal_sim = 3.08  	given: 7.50 	Differnce --> 4.42
# my_wu_pal_sim = 2.22  	given: 8.59 	Differnce --> 6.37
# my_wu_pal_sim = 5.71  	given: 6.34 	Differnce --> 0.63
# my_wu_pal_sim = 5.0  	given: 3.38 	Differnce --> 1.62
# my_wu_pal_sim = 6.15  	given: 6.00 	Differnce --> 0.15
# my_wu_pal_sim = 2.86  	given: 3.88 	Differnce --> 1.02
# my_wu_pal_sim = 7.06  	given: 7.63 	Differnce --> 0.57
# my_wu_pal_sim = 8.0  	given: 7.78 	Differnce --> 0.22
# my_wu_pal_sim = 10.0  	given: 9.22 	Differnce --> 0.78
# my_wu_pal_sim = 3.08  	given: 7.38 	Differnce --> 4.3
# my_wu_pal_sim = 3.33  	given: 6.09 	Differnce --> 2.76
# my_wu_pal_sim = 1.43  	given: 8.50 	Differnce --> 7.07
# my_wu_pal_sim = 8.0  	given: 8.31 	Differnce --> 0.31
# my_wu_pal_sim = 8.75  	given: 7.13 	Differnce --> 1.62
# my_wu_pal_sim = 5.0  	given: 5.91 	Differnce --> 0.91
# my_wu_pal_sim = 1.25  	given: 6.47 	Differnce --> 5.22
# my_wu_pal_sim = 4.62  	given: 3.38 	Differnce --> 1.24
# my_wu_pal_sim = 3.64  	given: 3.63 	Differnce --> 0.01
# my_wu_pal_sim = 0  	given: 7.13 	Differnce --> 7.13
# my_wu_pal_sim = 9.23  	given: 7.89 	Differnce --> 1.34
# my_wu_pal_sim = 2.22  	given: 5.97 	Differnce --> 3.75
# my_wu_pal_sim = 5.71  	given: 7.03 	Differnce --> 1.32
# my_wu_pal_sim = 3.08  	given: 7.69 	Differnce --> 4.61
# my_wu_pal_sim = 5.0  	given: 7.47 	Differnce --> 2.47
# my_wu_pal_sim = 8.57  	given: 6.19 	Differnce --> 2.38
# my_wu_pal_sim = 5.71  	given: 6.97 	Differnce --> 1.26
# my_wu_pal_sim = 3.75  	given: 3.56 	Differnce --> 0.19
# my_wu_pal_sim = 3.64  	given: 7.47 	Differnce --> 3.83
# my_wu_pal_sim = 9.09  	given: 8.34 	Differnce --> 0.75
# my_wu_pal_sim = 8.57  	given: 8.70 	Differnce --> 0.13
# my_wu_pal_sim = 7.69  	given: 7.81 	Differnce --> 0.12
# my_wu_pal_sim = 3.75  	given: 5.70 	Differnce --> 1.95
# my_wu_pal_sim = 5.71  	given: 6.22 	Differnce --> 0.51
# my_wu_pal_sim = 5.56  	given: 6.34 	Differnce --> 0.78
# my_wu_pal_sim = 5.45  	given: 4.06 	Differnce --> 1.39
# my_wu_pal_sim = 5.71  	given: 4.47 	Differnce --> 1.24
# my_wu_pal_sim = 8.89  	given: 5.97 	Differnce --> 2.92
# my_wu_pal_sim = 7.27  	given: 7.61 	Differnce --> 0.34
# my_wu_pal_sim = 8.57  	given: 8.36 	Differnce --> 0.21
# my_wu_pal_sim = 2.86  	given: 7.41 	Differnce --> 4.55
# my_wu_pal_sim = 7.14  	given: 2.69 	Differnce --> 4.45
# my_wu_pal_sim = 7.69  	given: 3.94 	Differnce --> 3.75
# my_wu_pal_sim = 7.69  	given: 7.16 	Differnce --> 0.53
# my_wu_pal_sim = 3.33  	given: 5.63 	Differnce --> 2.3
# my_wu_pal_sim = 8.33  	given: 7.53 	Differnce --> 0.8
# my_wu_pal_sim = 5.45  	given: 8.31 	Differnce --> 2.86
# my_wu_pal_sim = 9.23  	given: 8.81 	Differnce --> 0.42
# my_wu_pal_sim = 6.67  	given: 6.25 	Differnce --> 0.42
# my_wu_pal_sim = 8.33  	given: 8.30 	Differnce --> 0.03
# my_wu_pal_sim = 6.67  	given: 5.25 	Differnce --> 1.42
# my_wu_pal_sim = 9.17  	given: 8.53 	Differnce --> 0.64
# my_wu_pal_sim = 2.35  	given: 7.94 	Differnce --> 5.59
# my_wu_pal_sim = 3.08  	given: 6.88 	Differnce --> 3.8
# my_wu_pal_sim = 4.29  	given: 5.94 	Differnce --> 1.65
# my_wu_pal_sim = 5.33  	given: 4.06 	Differnce --> 1.27
# my_wu_pal_sim = 3.64  	given: 6.25 	Differnce --> 2.61
# my_wu_pal_sim = 7.78  	given: 7.72 	Differnce --> 0.06
# my_wu_pal_sim = 4.0  	given: 6.19 	Differnce --> 2.19
# my_wu_pal_sim = 5.0  	given: 2.97 	Differnce --> 2.03
# my_wu_pal_sim = 1.67  	given: 1.94 	Differnce --> 0.27
# my_wu_pal_sim = 7.27  	given: 3.75 	Differnce --> 3.52
# my_wu_pal_sim = 6.67  	given: 3.31 	Differnce --> 3.36
# my_wu_pal_sim = 5.45  	given: 3.69 	Differnce --> 1.76
# my_wu_pal_sim = 8.0  	given: 7.44 	Differnce --> 0.56
# my_wu_pal_sim = 4.62  	given: 6.41 	Differnce --> 1.79
# my_wu_pal_sim = 5.45  	given: 5.44 	Differnce --> 0.01
# my_wu_pal_sim = 3.08  	given: 6.25 	Differnce --> 3.17
# my_wu_pal_sim = 2.86  	given: 2.63 	Differnce --> 0.23
# my_wu_pal_sim = 2.86  	given: 0.88 	Differnce --> 1.98
# my_wu_pal_sim = 8.33  	given: 3.19 	Differnce --> 5.14
# my_wu_pal_sim = 5.33  	given: 4.69 	Differnce --> 0.64
# my_wu_pal_sim = 6.15  	given: 6.75 	Differnce --> 0.6
# my_wu_pal_sim = 6.15  	given: 5.31 	Differnce --> 0.84
# my_wu_pal_sim = 4.0  	given: 7.31 	Differnce --> 3.31
# my_wu_pal_sim = 2.0  	given: 5.75 	Differnce --> 3.75
# my_wu_pal_sim = 7.5  	given: 3.97 	Differnce --> 3.53
# my_wu_pal_sim = 6.15  	given: 3.47 	Differnce --> 2.68
# my_wu_pal_sim = 8.0  	given: 3.63 	Differnce --> 4.37
# my_wu_pal_sim = 5.45  	given: 5.56 	Differnce --> 0.11
# my_wu_pal_sim = 9.23  	given: 7.83 	Differnce --> 1.4
# my_wu_pal_sim = 5.0  	given: 3.88 	Differnce --> 1.12
# my_wu_pal_sim = 4.29  	given: 5.31 	Differnce --> 1.02
# my_wu_pal_sim = 1.43  	given: 6.81 	Differnce --> 5.38
# my_wu_pal_sim = 8.57  	given: 7.59 	Differnce --> 0.98
# my_wu_pal_sim = 6.25  	given: 7.19 	Differnce --> 0.94
# my_wu_pal_sim = 7.06  	given: 4.38 	Differnce --> 2.68
# my_wu_pal_sim = 5.71  	given: 6.53 	Differnce --> 0.82
# my_wu_pal_sim = 5.88  	given: 6.19 	Differnce --> 0.31
# my_wu_pal_sim = 5.71  	given: 7.69 	Differnce --> 1.98
# my_wu_pal_sim = 7.0  	given: 6.31 	Differnce --> 0.69
# my_wu_pal_sim = 6.36  	given: 6.03 	Differnce --> 0.33
# my_wu_pal_sim = 1.33  	given: 8.34 	Differnce --> 7.01
# my_wu_pal_sim = 5.0  	given: 6.25 	Differnce --> 1.25
# my_wu_pal_sim = 5.26  	given: 6.34 	Differnce --> 1.08
# my_wu_pal_sim = 3.08  	given: 3.78 	Differnce --> 0.7

# %% [markdown]
# ### Save result in a list

# %%
wu_result = sim_res_list(wu_pal_sim)

# %% [markdown]
# ### Print more result

# %%
for val in VALUES:
    syns1 = get_synsets(val[0])
    syns2 = get_synsets(val[1])
    
    #? Print the VALUES whose synsets I could not find or that returned similarity of 0
    if(syns1 is not None and syns2 is not None):
        sim = max_similarity(syns1, syns2, my_wu_pal_sim)
        # wn_sim = wu_pal_sim(syns1, syns2)
        print(f'Similarity between {sim[0]} and {sim[1]}:')
        print(f'my_WUP = {sim[2]}, the given similarity is: {val[2]}')
        
        # print(f'WN original WUP Similarity between {wn_sim[0]} and {wn_sim[1]}: {wn_sim[2]}\n')
                
        if(sim[2] == 0):
            print("SIMILARiTY = 0. Real value by WUP of ", sim[0], ";", sim[1], ":", wu_pal_sim(sim[0], sim[1]))
    else:
        print("-- Empty Synsets:", val[0], val[1])
# Out:
# Similarity between Synset('sexual_love.n.02') and Synset('sexual_activity.n.01'):
# my_WUP = 9.23, the given similarity is: 6.77
# Similarity between Synset('tiger.n.02') and Synset('big_cat.n.01'):
# my_WUP = 9.66, the given similarity is: 7.35
# Similarity between Synset('tiger.n.02') and Synset('tiger.n.02'):
# my_WUP = 10.0, the given similarity is: 10.00
# Similarity between Synset('book.n.11') and Synset('newspaper.n.03'):
# my_WUP = 8.75, the given similarity is: 7.46
# Similarity between Synset('computer.n.01') and Synset('keyboard.n.01'):
# my_WUP = 8.24, the given similarity is: 7.62
# Similarity between Synset('computer.n.01') and Synset('internet.n.01'):
# my_WUP = 6.32, the given similarity is: 7.58
# Similarity between Synset('airplane.n.01') and Synset('car.n.02'):
# my_WUP = 7.27, the given similarity is: 5.77
# Similarity between Synset('train.n.01') and Synset('car.n.02'):
# my_WUP = 7.37, the given similarity is: 6.31
# Similarity between Synset('telephone.n.02') and Synset('communication.n.02'):
# my_WUP = 1.67, the given similarity is: 7.50
# Similarity between Synset('television_receiver.n.01') and Synset('radio_receiver.n.01'):
# my_WUP = 9.09, the given similarity is: 6.77
# Similarity between Synset('medium.n.01') and Synset('radio.n.01'):
# my_WUP = 8.24, the given similarity is: 7.42
# Similarity between Synset('drug.n.01') and Synset('abuse.n.02'):
# my_WUP = 1.82, the given similarity is: 6.85
# Similarity between Synset('bread.n.01') and Synset('butter.n.01'):
# my_WUP = 7.5, the given similarity is: 6.19
# Similarity between Synset('cucumber.n.02') and Synset('potato.n.01'):
# my_WUP = 8.24, the given similarity is: 5.92
# Similarity between Synset('doctor.n.01') and Synset('nurse.n.01'):
# my_WUP = 8.24, the given similarity is: 7.00
# Similarity between Synset('professor.n.01') and Synset('doctor.n.01'):
# my_WUP = 6.67, the given similarity is: 6.62
# Similarity between Synset('scholar.n.01') and Synset('professor.n.01'):
# my_WUP = 5.33, the given similarity is: 6.81
# Similarity between Synset('smart.n.01') and Synset('scholar.n.01'):
# my_WUP = 1.33, the given similarity is: 4.62
# Similarity between Synset('smart.n.01') and Synset('stupid.n.01'):
# my_WUP = 1.33, the given similarity is: 5.81
# Similarity between Synset('party.n.03') and Synset('lineage.n.01'):
# my_WUP = 6.15, the given similarity is: 7.08
# Similarity between Synset('stock.n.14') and Synset('marketplace.n.02'):
# my_WUP = 5.56, the given similarity is: 8.08
# Similarity between Synset('stock.n.03') and Synset('earphone.n.01'):
# my_WUP = 7.0, the given similarity is: 1.62
# Similarity between Synset('stock.n.03') and Synset('compact_disk.n.01'):
# my_WUP = 7.37, the given similarity is: 1.31
# Similarity between Synset('livestock.n.01') and Synset('jaguar.n.01'):
# my_WUP = 8.15, the given similarity is: 0.92
# Similarity between Synset('broth.n.01') and Synset('egg.n.02'):
# my_WUP = 6.25, the given similarity is: 1.81
# Similarity between Synset('richness.n.05') and Synset('egg.n.02'):
# my_WUP = 1.54, the given similarity is: 6.69
# Similarity between Synset('sprout.v.02') and Synset('know.v.05'):
# my_WUP = 2.86, the given similarity is: 3.73
# Similarity between Synset('stock.n.11') and Synset('life.n.10'):
# my_WUP = 6.15, the given similarity is: 0.92
# Similarity between Synset('book.n.07') and Synset('library.n.04'):
# my_WUP = 8.0, the given similarity is: 7.46
# Similarity between Synset('bank.n.06') and Synset('money.n.02'):
# my_WUP = 5.71, the given similarity is: 8.12
# Similarity between Synset('forest.n.01') and Synset('forest.n.01'):
# my_WUP = 10.0, the given similarity is: 7.73
# Similarity between Synset('money.n.03') and Synset('cash.n.01'):
# my_WUP = 8.75, the given similarity is: 9.15
# Similarity between Synset('professor.n.01') and Synset('cucumber.n.01'):
# my_WUP = 5.0, the given similarity is: 0.31
# Similarity between Synset('king.n.02') and Synset('cabbage.n.03'):
# my_WUP = 5.71, the given similarity is: 0.23
# Similarity between Synset('king.n.02') and Synset('king.n.02'):
# my_WUP = 10.0, the given similarity is: 8.58
# Similarity between Synset('king.n.10') and Synset('castle.n.03'):
# my_WUP = 9.09, the given similarity is: 5.92
# Similarity between Synset('bishop.n.01') and Synset('rabbi.n.01'):
# my_WUP = 7.5, the given similarity is: 6.69
# Similarity between Synset('jerusalem.n.01') and Synset('israel.n.01'):
# my_WUP = 7.0, the given similarity is: 8.46
# Similarity between Synset('jerusalem.n.01') and Synset('palestinian.n.01'):
# my_WUP = 2.73, the given similarity is: 7.65
# Similarity between Synset('holy_place.n.01') and Synset('sexual_activity.n.01'):
# my_WUP = 3.08, the given similarity is: 1.62
# Similarity between Synset('fuck.n.01') and Synset('sexual_activity.n.01'):
# my_WUP = 8.57, the given similarity is: 9.44
# -- Empty Synsets: Maradona football
# Similarity between Synset('football.n.01') and Synset('soccer.n.01'):
# my_WUP = 9.52, the given similarity is: 9.03
# Similarity between Synset('football.n.02') and Synset('basketball.n.02'):
# my_WUP = 9.0, the given similarity is: 6.81
# Similarity between Synset('football.n.01') and Synset('tennis.n.01'):
# my_WUP = 7.62, the given similarity is: 6.63
# Similarity between Synset('tennis.n.01') and Synset('racket.n.02'):
# my_WUP = 6.0, the given similarity is: 7.56
# Similarity between Synset('arafat.n.01') and Synset('peace.n.01'):
# my_WUP = 1.43, the given similarity is: 6.73
# Similarity between Synset('arafat.n.01') and Synset('terror.n.02'):
# my_WUP = 6.15, the given similarity is: 7.65
# Similarity between Synset('arafat.n.01') and Synset('jackson.n.04'):
# my_WUP = 8.0, the given similarity is: 2.50
# Similarity between Synset('law.n.01') and Synset('lawyer.n.01'):
# my_WUP = 1.67, the given similarity is: 8.38
# Similarity between Synset('movie.n.01') and Synset('star.n.03'):
# my_WUP = 5.33, the given similarity is: 7.38
# Similarity between Synset('movie.n.01') and Synset('popcorn.n.01'):
# my_WUP = 3.64, the given similarity is: 6.19
# Similarity between Synset('movie.n.01') and Synset('critic.n.03'):
# my_WUP = 4.44, the given similarity is: 6.73
# Similarity between Synset('movie.n.01') and Synset('theater.n.01'):
# my_WUP = 6.25, the given similarity is: 7.92
# Similarity between Synset('purgative.n.01') and Synset('proton.n.01'):
# my_WUP = 2.22, the given similarity is: 8.12
# Similarity between Synset('physics.n.02') and Synset('chemistry.n.01'):
# my_WUP = 9.0, the given similarity is: 7.35
# Similarity between Synset('space.n.01') and Synset('chemistry.n.03'):
# my_WUP = 4.44, the given similarity is: 4.88
# Similarity between Synset('alcohol.n.02') and Synset('chemistry.n.02'):
# my_WUP = 6.67, the given similarity is: 5.54
# Similarity between Synset('vodka.n.01') and Synset('gin.n.01'):
# my_WUP = 8.89, the given similarity is: 8.46
# Similarity between Synset('vodka.n.01') and Synset('brandy.n.01'):
# my_WUP = 8.89, the given similarity is: 8.13
# Similarity between Synset('drink.n.04') and Synset('car.n.02'):
# my_WUP = 2.86, the given similarity is: 3.04
# Similarity between Synset('drink.n.04') and Synset('auricle.n.02'):
# my_WUP = 4.62, the given similarity is: 1.31
# Similarity between Synset('drink.n.02') and Synset('sass.n.01'):
# my_WUP = 5.0, the given similarity is: 5.96
# Similarity between Synset('drink.v.02') and Synset('feed.v.06'):
# my_WUP = 5.0, the given similarity is: 6.87
# Similarity between Synset('baby.n.05') and Synset('mother.n.03'):
# my_WUP = 7.5, the given similarity is: 7.85
# Similarity between Synset('beverage.n.01') and Synset('mother.n.02'):
# my_WUP = 6.15, the given similarity is: 2.65
# Similarity between Synset('car.n.01') and Synset('car.n.01'):
# my_WUP = 10.0, the given similarity is: 8.94
# Similarity between Synset('jewel.n.01') and Synset('jewel.n.01'):
# my_WUP = 10.0, the given similarity is: 8.96
# Similarity between Synset('journey.n.01') and Synset('voyage.n.02'):
# my_WUP = 9.52, the given similarity is: 9.29
# Similarity between Synset('male_child.n.01') and Synset('cub.n.02'):
# my_WUP = 9.23, the given similarity is: 8.83
# Similarity between Synset('seashore.n.01') and Synset('shore.n.01'):
# my_WUP = 9.09, the given similarity is: 9.10
# Similarity between Synset('mental_hospital.n.01') and Synset('bedlam.n.02'):
# my_WUP = 9.52, the given similarity is: 8.87
# Similarity between Synset('sorcerer.n.01') and Synset('sorcerer.n.01'):
# my_WUP = 10.0, the given similarity is: 9.02
# Similarity between Synset('noon.n.01') and Synset('noon.n.01'):
# my_WUP = 10.0, the given similarity is: 9.29
# Similarity between Synset('furnace.n.01') and Synset('stove.n.02'):
# my_WUP = 5.26, the given similarity is: 8.79
# Similarity between Synset('food.n.03') and Synset('fruit.n.03'):
# my_WUP = 4.0, the given similarity is: 7.52
# Similarity between Synset('bird.n.01') and Synset('cock.n.05'):
# my_WUP = 9.52, the given similarity is: 7.10
# Similarity between Synset('bird.n.01') and Synset('crane.n.05'):
# my_WUP = 8.7, the given similarity is: 7.38
# Similarity between Synset('tool.n.01') and Synset('implement.n.01'):
# my_WUP = 9.33, the given similarity is: 6.46
# Similarity between Synset('brother.n.05') and Synset('monk.n.01'):
# my_WUP = 9.33, the given similarity is: 6.27
# Similarity between Synset('crane.n.04') and Synset('implement.n.01'):
# my_WUP = 7.5, the given similarity is: 2.69
# Similarity between Synset('chap.n.01') and Synset('brother.n.04'):
# my_WUP = 6.67, the given similarity is: 4.46
# Similarity between Synset('journey.n.01') and Synset('car.n.02'):
# my_WUP = 1.05, the given similarity is: 5.85
# Similarity between Synset('monk.n.01') and Synset('prophet.n.01'):
# my_WUP = 5.33, the given similarity is: 5.00
# Similarity between Synset('cemetery.n.01') and Synset('forest.n.02'):
# my_WUP = 4.29, the given similarity is: 2.08
# Similarity between Synset('food.n.02') and Synset('cock.n.04'):
# my_WUP = 2.11, the given similarity is: 4.42
# Similarity between Synset('coast.n.02') and Synset('hill.n.01'):
# my_WUP = 6.67, the given similarity is: 4.38
# Similarity between Synset('forest.n.02') and Synset('cemetery.n.01'):
# my_WUP = 4.29, the given similarity is: 1.85
# Similarity between Synset('shore.n.01') and Synset('forest.n.02'):
# my_WUP = 6.0, the given similarity is: 3.08
# Similarity between Synset('monk.n.01') and Synset('slave.n.03'):
# my_WUP = 6.67, the given similarity is: 0.92
# Similarity between Synset('coast.n.02') and Synset('forest.n.02'):
# my_WUP = 5.45, the given similarity is: 3.15
# Similarity between Synset('chap.n.01') and Synset('sorcerer.n.01'):
# my_WUP = 6.67, the given similarity is: 0.92
# Similarity between Synset('chord.n.02') and Synset('smile.n.01'):
# my_WUP = 3.75, the given similarity is: 0.54
# Similarity between Synset('glass.n.02') and Synset('sorcerer.n.01'):
# my_WUP = 4.71, the given similarity is: 2.08
# Similarity between Synset('noon.n.01') and Synset('string.n.09'):
# my_WUP = 2.67, the given similarity is: 0.54
# Similarity between Synset('cock.n.04') and Synset('voyage.n.02'):
# my_WUP = 0.8, the given similarity is: 0.62
# Similarity between Synset('money.n.03') and Synset('dollar.n.03'):
# my_WUP = 7.78, the given similarity is: 8.42
# Similarity between Synset('money.n.03') and Synset('cash.n.01'):
# my_WUP = 8.75, the given similarity is: 9.08
# Similarity between Synset('money.n.03') and Synset('currency.n.01'):
# my_WUP = 9.33, the given similarity is: 9.04
# Similarity between Synset('money.n.02') and Synset('wealth.n.04'):
# my_WUP = 9.23, the given similarity is: 8.27
# Similarity between Synset('money.n.02') and Synset('property.n.01'):
# my_WUP = 8.33, the given similarity is: 7.57
# Similarity between Synset('money.n.02') and Synset('possession.n.02'):
# my_WUP = 7.27, the given similarity is: 7.29
# Similarity between Synset('money.n.02') and Synset('bank.n.06'):
# my_WUP = 5.71, the given similarity is: 8.50
# Similarity between Synset('money.n.01') and Synset('deposit.n.04'):
# my_WUP = 8.75, the given similarity is: 7.73
# Similarity between Synset('money.n.02') and Synset('withdrawal.n.03'):
# my_WUP = 2.86, the given similarity is: 6.88
# Similarity between Synset('money.n.02') and Synset('laundering.n.01'):
# my_WUP = 2.5, the given similarity is: 5.65
# Similarity between Synset('money.n.02') and Synset('process.n.02'):
# my_WUP = 3.33, the given similarity is: 3.31
# Similarity between Synset('tiger.n.02') and Synset('jaguar.n.01'):
# my_WUP = 9.33, the given similarity is: 8.00
# Similarity between Synset('tiger.n.02') and Synset('feline.n.01'):
# my_WUP = 9.29, the given similarity is: 8.00
# Similarity between Synset('tiger.n.02') and Synset('carnivore.n.01'):
# my_WUP = 8.89, the given similarity is: 7.08
# Similarity between Synset('tiger.n.02') and Synset('mammal.n.01'):
# my_WUP = 8.0, the given similarity is: 6.85
# Similarity between Synset('tiger.n.01') and Synset('animal.n.01'):
# my_WUP = 8.0, the given similarity is: 7.00
# Similarity between Synset('tiger.n.01') and Synset('organism.n.01'):
# my_WUP = 8.57, the given similarity is: 4.77
# Similarity between Synset('tiger.n.01') and Synset('animal.n.01'):
# my_WUP = 8.0, the given similarity is: 5.62
# Similarity between Synset('tiger.n.01') and Synset('menagerie.n.02'):
# my_WUP = 5.33, the given similarity is: 5.87
# Similarity between Synset('psychology.n.01') and Synset('psychiatry.n.01'):
# my_WUP = 7.27, the given similarity is: 8.08
# Similarity between Synset('psychology.n.01') and Synset('anxiety.n.02'):
# my_WUP = 2.5, the given similarity is: 7.00
# Similarity between Synset('psychology.n.01') and Synset('fear.n.03'):
# my_WUP = 2.5, the given similarity is: 6.85
# Similarity between Synset('psychology.n.01') and Synset('depression.n.10'):
# my_WUP = 3.53, the given similarity is: 7.42
# Similarity between Synset('psychology.n.01') and Synset('clinic.n.01'):
# my_WUP = 2.35, the given similarity is: 6.58
# Similarity between Synset('psychology.n.01') and Synset('doctor.n.03'):
# my_WUP = 3.33, the given similarity is: 6.42
# Similarity between Synset('psychology.n.01') and Synset('freud.n.01'):
# my_WUP = 0.95, the given similarity is: 8.21
# Similarity between Synset('psychology.n.01') and Synset('mind.n.06'):
# my_WUP = 5.88, the given similarity is: 7.69
# Similarity between Synset('psychology.n.01') and Synset('health.n.02'):
# my_WUP = 2.67, the given similarity is: 7.23
# Similarity between Synset('psychology.n.01') and Synset('science.n.01'):
# my_WUP = 9.41, the given similarity is: 6.71
# Similarity between Synset('psychology.n.01') and Synset('discipline.n.01'):
# my_WUP = 8.75, the given similarity is: 5.58
# Similarity between Synset('psychology.n.01') and Synset('cognition.n.01'):
# my_WUP = 6.15, the given similarity is: 7.48
# Similarity between Synset('planet.n.03') and Synset('star.n.03'):
# my_WUP = 8.57, the given similarity is: 8.45
# Similarity between Synset('planet.n.03') and Synset('constellation.n.02'):
# my_WUP = 7.69, the given similarity is: 8.06
# Similarity between Synset('planet.n.03') and Synset('moon.n.06'):
# my_WUP = 8.0, the given similarity is: 8.08
# Similarity between Synset('planet.n.03') and Synset('sun.n.04'):
# my_WUP = 8.0, the given similarity is: 8.02
# Similarity between Synset('satellite.n.02') and Synset('galax.n.01'):
# my_WUP = 6.32, the given similarity is: 8.11
# Similarity between Synset('planet.n.03') and Synset('quad.n.03'):
# my_WUP = 5.33, the given similarity is: 7.92
# Similarity between Synset('satellite.n.02') and Synset('astronomer.n.01'):
# my_WUP = 6.15, the given similarity is: 7.94
# Similarity between Synset('precedent.n.01') and Synset('example.n.01'):
# my_WUP = 9.23, the given similarity is: 5.85
# Similarity between Synset('precedent.n.01') and Synset('information.n.02'):
# my_WUP = 8.33, the given similarity is: 3.85
# Similarity between Synset('precedent.n.01') and Synset('cognition.n.01'):
# my_WUP = 7.27, the given similarity is: 2.81
# Similarity between Synset('common_law.n.02') and Synset('law.n.01'):
# my_WUP = 9.09, the given similarity is: 6.65
# Similarity between Synset('common_law.n.02') and Synset('collection.n.01'):
# my_WUP = 8.0, the given similarity is: 2.50
# Similarity between Synset('common_law.n.02') and Synset('group.n.01'):
# my_WUP = 6.67, the given similarity is: 1.77
# Similarity between Synset('precedent.n.04') and Synset('antecedent.n.04'):
# my_WUP = 6.15, the given similarity is: 6.04
# Similarity between Synset('cup.n.05') and Synset('coffee_bean.n.01'):
# my_WUP = 7.37, the given similarity is: 6.58
# Similarity between Synset('cup.n.01') and Synset('tableware.n.01'):
# my_WUP = 8.89, the given similarity is: 6.85
# Similarity between Synset('cup.n.01') and Synset('article.n.02'):
# my_WUP = 7.5, the given similarity is: 2.40
# Similarity between Synset('cup.n.07') and Synset('artifact.n.01'):
# my_WUP = 7.69, the given similarity is: 2.92
# Similarity between Synset('cup.n.07') and Synset('object.n.01'):
# my_WUP = 5.45, the given similarity is: 3.69
# Similarity between Synset('cup.n.02') and Synset('entity.n.01'):
# my_WUP = 2.86, the given similarity is: 2.15
# Similarity between Synset('cup.n.06') and Synset('beverage.n.01'):
# my_WUP = 7.5, the given similarity is: 7.25
# Similarity between Synset('cup.n.06') and Synset('food.n.01'):
# my_WUP = 6.67, the given similarity is: 5.00
# Similarity between Synset('cup.n.06') and Synset('substance.n.07'):
# my_WUP = 5.71, the given similarity is: 1.92
# Similarity between Synset('cup.n.06') and Synset('liquid.n.01'):
# my_WUP = 7.06, the given similarity is: 5.90
# Similarity between Synset('jaguar.n.01') and Synset('big_cat.n.01'):
# my_WUP = 9.66, the given similarity is: 7.42
# Similarity between Synset('jaguar.n.01') and Synset('car.n.02'):
# my_WUP = 3.33, the given similarity is: 7.27
# Similarity between Synset('energy.n.06') and Synset('repository.n.02'):
# my_WUP = 2.86, the given similarity is: 1.81
# Similarity between Synset('repository.n.02') and Synset('senate.n.01'):
# my_WUP = 1.33, the given similarity is: 5.06
# Similarity between Synset('energy.n.06') and Synset('testing_ground.n.01'):
# my_WUP = 3.08, the given similarity is: 5.09
# Similarity between Synset('calculator.n.01') and Synset('testing_ground.n.01'):
# my_WUP = 4.0, the given similarity is: 6.78
# Similarity between Synset('weapon.n.02') and Synset('secret.n.02'):
# my_WUP = 2.86, the given similarity is: 6.06
# Similarity between Synset('federal_bureau_of_investigation.n.01') and Synset('fingerprint.n.01'):
# my_WUP = 2.5, the given similarity is: 6.94
# Similarity between Synset('federal_bureau_of_investigation.n.01') and Synset('investigation.n.02'):
# my_WUP = 2.22, the given similarity is: 8.31
# Similarity between Synset('investigation.n.02') and Synset('effort.n.02'):
# my_WUP = 8.24, the given similarity is: 4.59
# Similarity between Synset('mars.n.01') and Synset('water_system.n.02'):
# my_WUP = 5.0, the given similarity is: 2.94
# Similarity between Synset('mars.n.01') and Synset('scientist.n.01'):
# my_WUP = 4.71, the given similarity is: 5.63
# Similarity between Synset('news.n.02') and Synset('report.n.03'):
# my_WUP = 9.23, the given similarity is: 8.16
# Similarity between Synset('canyon.n.01') and Synset('landscape.n.03'):
# my_WUP = 3.53, the given similarity is: 7.53
# Similarity between Synset('effigy.n.01') and Synset('surface.n.01'):
# my_WUP = 7.14, the given similarity is: 4.56
# Similarity between Synset('discovery.n.01') and Synset('space.n.01'):
# my_WUP = 4.0, the given similarity is: 6.34
# Similarity between Synset('water.n.03') and Synset('seepage.n.01'):
# my_WUP = 2.5, the given similarity is: 6.56
# Similarity between Synset('signboard.n.01') and Synset('recess.n.04'):
# my_WUP = 7.5, the given similarity is: 2.38
# Similarity between Synset('wednesday.n.01') and Synset('news.n.04'):
# my_WUP = 2.67, the given similarity is: 2.22
# Similarity between Synset('mile.n.07') and Synset('kilometer.n.01'):
# my_WUP = 8.0, the given similarity is: 8.66
# Similarity between Synset('calculator.n.01') and Synset('news.n.04'):
# my_WUP = 1.67, the given similarity is: 4.47
# Similarity between Synset('district.n.01') and Synset('surface.n.03'):
# my_WUP = 6.15, the given similarity is: 5.34
# Similarity between Synset('atmosphere.n.03') and Synset('landscape.n.01'):
# my_WUP = 5.0, the given similarity is: 3.69
# Similarity between Synset('president_of_the_united_states.n.02') and Synset('decoration.n.02'):
# my_WUP = 2.35, the given similarity is: 3.00
# Similarity between Synset('war.n.02') and Synset('troop.n.04'):
# my_WUP = 3.08, the given similarity is: 8.13
# Similarity between Synset('record.n.03') and Synset('number.n.02'):
# my_WUP = 9.09, the given similarity is: 6.31
# Similarity between Synset('skin.n.02') and Synset('eye.n.05'):
# my_WUP = 6.67, the given similarity is: 6.22
# Similarity between Synset('japanese.n.01') and Synset('american.n.03'):
# my_WUP = 7.69, the given similarity is: 6.50
# Similarity between Synset('dramaturgy.n.01') and Synset('history.n.05'):
# my_WUP = 5.0, the given similarity is: 3.91
# Similarity between Synset('volunteer.n.02') and Synset('motto.n.01'):
# my_WUP = 1.54, the given similarity is: 2.56
# Similarity between Synset('bias.n.01') and Synset('recognition.n.07'):
# my_WUP = 6.67, the given similarity is: 3.00
# Similarity between Synset('decoration.n.02') and Synset('heroism.n.01'):
# my_WUP = 2.67, the given similarity is: 5.63
# Similarity between Synset('century.n.01') and Synset('year.n.03'):
# my_WUP = 8.33, the given similarity is: 7.59
# Similarity between Synset('century.n.01') and Synset('nation.n.02'):
# my_WUP = 3.64, the given similarity is: 3.16
# Similarity between Synset('delay.n.02') and Synset('racism.n.02'):
# my_WUP = 6.25, the given similarity is: 1.19
# Similarity between Synset('delay.n.02') and Synset('news_program.n.01'):
# my_WUP = 5.33, the given similarity is: 3.31
# Similarity between Synset('curate.n.01') and Synset('party.n.05'):
# my_WUP = 6.15, the given similarity is: 6.63
# Similarity between Synset('peace.n.01') and Synset('design.n.02'):
# my_WUP = 3.08, the given similarity is: 4.75
# Similarity between Synset('minority.n.03') and Synset('peace.n.01'):
# my_WUP = 6.15, the given similarity is: 3.69
# Similarity between Synset('attempt.n.01') and Synset('peace.n.01'):
# my_WUP = 3.08, the given similarity is: 4.25
# Similarity between Synset('government.n.02') and Synset('crisis.n.02'):
# my_WUP = 5.71, the given similarity is: 6.56
# Similarity between Synset('deployment.n.01') and Synset('departure.n.01'):
# my_WUP = 7.14, the given similarity is: 4.25
# Similarity between Synset('deployment.n.01') and Synset('coitus_interruptus.n.01'):
# my_WUP = 7.78, the given similarity is: 5.88
# Similarity between Synset('energy.n.05') and Synset('crisis.n.01'):
# my_WUP = 6.25, the given similarity is: 5.94
# Similarity between Synset('announcement.n.02') and Synset('news.n.04'):
# my_WUP = 6.67, the given similarity is: 7.56
# Similarity between Synset('announcement.n.02') and Synset('attempt.n.01'):
# my_WUP = 3.08, the given similarity is: 2.75
# Similarity between Synset('stroke.n.07') and Synset('hospital.n.01'):
# my_WUP = 4.0, the given similarity is: 7.03
# Similarity between Synset('disability.n.01') and Synset('end.n.06'):
# my_WUP = 5.33, the given similarity is: 5.47
# Similarity between Synset('victim.n.02') and Synset('hand_brake.n.01'):
# my_WUP = 4.44, the given similarity is: 6.47
# Similarity between Synset('discussion.n.01') and Synset('recovery.n.03'):
# my_WUP = 7.69, the given similarity is: 7.91
# Similarity between Synset('diary.n.01') and Synset('association.n.08'):
# my_WUP = 4.0, the given similarity is: 4.97
# Similarity between Synset('doctor.n.03') and Synset('force.n.04'):
# my_WUP = 2.67, the given similarity is: 5.00
# Similarity between Synset('doctor.n.03') and Synset('liability.n.03'):
# my_WUP = 2.67, the given similarity is: 5.19
# Similarity between Synset('liability.n.01') and Synset('indemnity.n.01'):
# my_WUP = 6.25, the given similarity is: 7.03
# Similarity between Synset('school.n.02') and Synset('center.n.03'):
# my_WUP = 8.75, the given similarity is: 3.44
# Similarity between Synset('rationality.n.01') and Synset('high_blood_pressure.n.01'):
# my_WUP = 5.56, the given similarity is: 2.31
# Similarity between Synset('reason.n.06') and Synset('criterion.n.02'):
# my_WUP = 5.33, the given similarity is: 5.91
# Similarity between Synset('hundred.n.01') and Synset('percentage.n.01'):
# my_WUP = 2.5, the given similarity is: 7.38
# Similarity between Synset('harvard.n.02') and Synset('yale.n.02'):
# my_WUP = 8.89, the given similarity is: 8.13
# Similarity between Synset('hospital.n.02') and Synset('infrastructure.n.01'):
# my_WUP = 2.67, the given similarity is: 4.63
# Similarity between Synset('death.n.08') and Synset('rowing.n.01'):
# my_WUP = 5.0, the given similarity is: 5.25
# Similarity between Synset('death.n.02') and Synset('convict.n.01'):
# my_WUP = 2.86, the given similarity is: 5.03
# Similarity between Synset('lawyer.n.01') and Synset('evidence.n.02'):
# my_WUP = 1.67, the given similarity is: 6.69
# Similarity between Synset('life.n.11') and Synset('death.n.02'):
# my_WUP = 8.57, the given similarity is: 7.88
# Similarity between Synset('life_sentence.n.01') and Synset('term.n.02'):
# my_WUP = 8.57, the given similarity is: 4.50
# Similarity between Synset('son.n.02') and Synset('similarity.n.02'):
# my_WUP = 4.55, the given similarity is: 4.75
# Similarity between Synset('board.n.01') and Synset('recommendation.n.03'):
# my_WUP = 2.67, the given similarity is: 4.47
# Similarity between Synset('governor.n.01') and Synset('consultation.n.01'):
# my_WUP = 1.33, the given similarity is: 3.25
# Similarity between Synset('organization_of_petroleum-exporting_countries.n.01') and Synset('state.n.04'):
# my_WUP = 6.25, the given similarity is: 5.63
# Similarity between Synset('peace.n.04') and Synset('atmosphere.n.01'):
# my_WUP = 7.14, the given similarity is: 3.69
# Similarity between Synset('peace.n.04') and Synset('indemnity.n.01'):
# my_WUP = 8.24, the given similarity is: 2.94
# Similarity between Synset('territory.n.02') and Synset('kilometer.n.01'):
# my_WUP = 2.5, the given similarity is: 5.28
# Similarity between Synset('locomotion.n.02') and Synset('activity.n.01'):
# my_WUP = 6.67, the given similarity is: 5.00
# Similarity between Synset('rival.n.01') and Synset('price.n.07'):
# my_WUP = 5.0, the given similarity is: 6.44
# Similarity between Synset('consumer.n.01') and Synset('confidence.n.05'):
# my_WUP = 1.54, the given similarity is: 4.13
# Similarity between Synset('consumer.n.01') and Synset('energy.n.06'):
# my_WUP = 3.08, the given similarity is: 4.75
# Similarity between Synset('trouble.n.01') and Synset('airport.n.01'):
# my_WUP = 1.33, the given similarity is: 2.38
# Similarity between Synset('car.n.02') and Synset('flight.n.03'):
# my_WUP = 5.88, the given similarity is: 4.94
# Similarity between Synset('recognition.n.03') and Synset('calling_card.n.02'):
# my_WUP = 6.15, the given similarity is: 8.06
# Similarity between Synset('recognition.n.03') and Synset('information.n.01'):
# my_WUP = 7.27, the given similarity is: 5.31
# Similarity between Synset('hotel.n.01') and Synset('reservation.n.01'):
# my_WUP = 3.75, the given similarity is: 8.03
# Similarity between Synset('grocery.n.02') and Synset('money.n.02'):
# my_WUP = 1.33, the given similarity is: 5.94
# Similarity between Synset('adjustment.n.03') and Synset('arrangement.n.06'):
# my_WUP = 6.67, the given similarity is: 6.00
# Similarity between Synset('arrangement.n.06') and Synset('accommodation.n.05'):
# my_WUP = 6.67, the given similarity is: 5.41
# Similarity between Synset('month.n.02') and Synset('hotel.n.01'):
# my_WUP = 1.54, the given similarity is: 1.81
# Similarity between Synset('type.n.01') and Synset('kind.n.01'):
# my_WUP = 9.47, the given similarity is: 8.97
# Similarity between Synset('arrival.n.03') and Synset('hotel.n.01'):
# my_WUP = 4.71, the given similarity is: 6.00
# Similarity between Synset('bed.n.01') and Synset('wardrobe.n.01'):
# my_WUP = 8.42, the given similarity is: 6.72
# Similarity between Synset('closet.n.04') and Synset('apparel.n.01'):
# my_WUP = 5.88, the given similarity is: 8.00
# Similarity between Synset('position.n.06') and Synset('decision.n.01'):
# my_WUP = 6.25, the given similarity is: 4.81
# Similarity between Synset('situation.n.01') and Synset('isolation.n.01'):
# my_WUP = 7.27, the given similarity is: 3.88
# Similarity between Synset('impartiality.n.01') and Synset('pastime.n.01'):
# my_WUP = 4.0, the given similarity is: 5.16
# Similarity between Synset('steering.n.02') and Synset('combination.n.06'):
# my_WUP = 6.67, the given similarity is: 2.25
# Similarity between Synset('street.n.03') and Synset('place.n.13'):
# my_WUP = 6.15, the given similarity is: 6.44
# Similarity between Synset('street.n.01') and Synset('avenue.n.02'):
# my_WUP = 9.47, the given similarity is: 8.88
# Similarity between Synset('street.n.02') and Synset('block.n.01'):
# my_WUP = 6.67, the given similarity is: 6.88
# Similarity between Synset('street.n.02') and Synset('child.n.03'):
# my_WUP = 4.71, the given similarity is: 4.94
# Similarity between Synset('listing.n.02') and Synset('proximity.n.03'):
# my_WUP = 3.16, the given similarity is: 2.56
# Similarity between Synset('listing.n.02') and Synset('category.n.02'):
# my_WUP = 3.75, the given similarity is: 6.38
# Similarity between Synset('cellular_telephone.n.01') and Synset('telephone.n.01'):
# my_WUP = 9.0, the given similarity is: 7.81
# Similarity between Synset('production.n.01') and Synset('hike.n.01'):
# my_WUP = 5.88, the given similarity is: 1.75
# Similarity between Synset('benchmark.n.01') and Synset('index.n.01'):
# my_WUP = 7.69, the given similarity is: 4.25
# Similarity between Synset('medium.n.03') and Synset('trading.n.01'):
# my_WUP = 6.25, the given similarity is: 3.88
# Similarity between Synset('medium.n.08') and Synset('profit.n.02'):
# my_WUP = 5.0, the given similarity is: 2.88
# Similarity between Synset('dividend.n.03') and Synset('payment.n.01'):
# my_WUP = 8.89, the given similarity is: 7.63
# Similarity between Synset('dividend.n.02') and Synset('calculation.n.01'):
# my_WUP = 2.86, the given similarity is: 6.48
# Similarity between Synset('calculation.n.02') and Synset('calculation.n.02'):
# my_WUP = 10.0, the given similarity is: 8.44
# Similarity between Synset('currency.n.02') and Synset('market.n.02'):
# my_WUP = 3.08, the given similarity is: 7.50
# Similarity between Synset('organization_of_petroleum-exporting_countries.n.01') and Synset('oil.n.02'):
# my_WUP = 2.22, the given similarity is: 8.59
# Similarity between Synset('oil.n.02') and Synset('neckcloth.n.01'):
# my_WUP = 5.71, the given similarity is: 6.34
# Similarity between Synset('announcement.n.02') and Synset('production.n.02'):
# my_WUP = 5.0, the given similarity is: 3.38
# Similarity between Synset('announcement.n.02') and Synset('admonition.n.01'):
# my_WUP = 6.15, the given similarity is: 6.00
# Similarity between Synset('profit.n.02') and Synset('admonition.n.01'):
# my_WUP = 2.86, the given similarity is: 3.88
# Similarity between Synset('net_income.n.01') and Synset('loss.n.06'):
# my_WUP = 7.06, the given similarity is: 7.63
# Similarity between Synset('dollar.n.01') and Synset('yen.n.02'):
# my_WUP = 8.0, the given similarity is: 7.78
# Similarity between Synset('dollar.n.02') and Synset('dollar.n.02'):
# my_WUP = 10.0, the given similarity is: 9.22
# Similarity between Synset('dollar.n.04') and Synset('profit.n.02'):
# my_WUP = 3.08, the given similarity is: 7.38
# Similarity between Synset('dollar.n.04') and Synset('loss.n.01'):
# my_WUP = 3.33, the given similarity is: 6.09
# Similarity between Synset('calculator.n.01') and Synset('software.n.01'):
# my_WUP = 1.43, the given similarity is: 8.50
# Similarity between Synset('network.n.05') and Synset('hardware.n.02'):
# my_WUP = 8.0, the given similarity is: 8.31
# Similarity between Synset('telephone.n.01') and Synset('equipment.n.01'):
# my_WUP = 8.75, the given similarity is: 7.13
# Similarity between Synset('equipment.n.01') and Synset('maker.n.01'):
# my_WUP = 5.0, the given similarity is: 5.91
# Similarity between Synset('luxury.n.01') and Synset('car.n.02'):
# my_WUP = 1.25, the given similarity is: 6.47
# Similarity between Synset('five.n.01') and Synset('month.n.02'):
# my_WUP = 4.62, the given similarity is: 3.38
# Similarity between Synset('report_card.n.01') and Synset('addition.n.03'):
# my_WUP = 3.64, the given similarity is: 3.63
# Similarity between Synset('investor.n.01') and Synset('earn.v.02'):
# my_WUP = 0, the given similarity is: 7.13
# SIMILARiTY = 0. Real value by WUP of  Synset('investor.n.01') ; Synset('earn.v.02') : 1.82
# Similarity between Synset('liquid.n.01') and Synset('water.n.06'):
# my_WUP = 9.23, the given similarity is: 7.89
# Similarity between Synset('baseball.n.01') and Synset('season.n.03'):
# my_WUP = 2.22, the given similarity is: 5.97
# Similarity between Synset('game.n.02') and Synset('victory.n.01'):
# my_WUP = 5.71, the given similarity is: 7.03
# Similarity between Synset('game.n.06') and Synset('team.n.02'):
# my_WUP = 3.08, the given similarity is: 7.69
# Similarity between Synset('marathon.n.01') and Synset('dash.n.02'):
# my_WUP = 5.0, the given similarity is: 7.47
# Similarity between Synset('game.n.02') and Synset('series.n.04'):
# my_WUP = 8.57, the given similarity is: 6.19
# Similarity between Synset('game.n.02') and Synset('defeat.n.01'):
# my_WUP = 5.71, the given similarity is: 6.97
# Similarity between Synset('seven-spot.n.01') and Synset('series.n.05'):
# my_WUP = 3.75, the given similarity is: 3.56
# Similarity between Synset('seafood.n.01') and Synset('sea.n.01'):
# my_WUP = 3.64, the given similarity is: 7.47
# Similarity between Synset('seafood.n.01') and Synset('food.n.02'):
# my_WUP = 9.09, the given similarity is: 8.34
# Similarity between Synset('seafood.n.01') and Synset('lobster.n.01'):
# my_WUP = 8.57, the given similarity is: 8.70
# Similarity between Synset('lobster.n.01') and Synset('food.n.02'):
# my_WUP = 7.69, the given similarity is: 7.81
# Similarity between Synset('lobster.n.01') and Synset('wine.n.01'):
# my_WUP = 3.75, the given similarity is: 5.70
# Similarity between Synset('food.n.03') and Synset('planning.n.03'):
# my_WUP = 5.71, the given similarity is: 6.22
# Similarity between Synset('television.n.01') and Synset('archive.n.01'):
# my_WUP = 5.56, the given similarity is: 6.34
# Similarity between Synset('beginning.n.02') and Synset('year.n.03'):
# my_WUP = 5.45, the given similarity is: 4.06
# Similarity between Synset('start.n.01') and Synset('match.n.02'):
# my_WUP = 5.71, the given similarity is: 4.47
# Similarity between Synset('game.n.05') and Synset('turn.n.09'):
# my_WUP = 8.89, the given similarity is: 5.97
# Similarity between Synset('boxing.n.01') and Synset('round_of_golf.n.01'):
# my_WUP = 7.27, the given similarity is: 7.61
# Similarity between Synset('championship.n.02') and Synset('tournament.n.02'):
# my_WUP = 8.57, the given similarity is: 8.36
# Similarity between Synset('crusade.v.01') and Synset('kill.v.02'):
# my_WUP = 2.86, the given similarity is: 7.41
# Similarity between Synset('credit_line.n.01') and Synset('insurance.n.01'):
# my_WUP = 7.14, the given similarity is: 2.69
# Similarity between Synset('day.n.07') and Synset('summer.n.02'):
# my_WUP = 7.69, the given similarity is: 3.94
# Similarity between Synset('summer.n.02') and Synset('drought.n.02'):
# my_WUP = 7.69, the given similarity is: 7.16
# Similarity between Synset('summer.n.02') and Synset('nature.n.04'):
# my_WUP = 3.33, the given similarity is: 5.63
# Similarity between Synset('day.n.07') and Synset('dawn.n.03'):
# my_WUP = 8.33, the given similarity is: 7.53
# Similarity between Synset('nature.n.04') and Synset('environment.n.01'):
# my_WUP = 5.45, the given similarity is: 8.31
# Similarity between Synset('environment.n.01') and Synset('ecology.n.01'):
# my_WUP = 9.23, the given similarity is: 8.81
# Similarity between Synset('nature.n.02') and Synset('man.n.03'):
# my_WUP = 6.67, the given similarity is: 6.25
# Similarity between Synset('man.n.01') and Synset('woman.n.01'):
# my_WUP = 8.33, the given similarity is: 8.30
# Similarity between Synset('man.n.03') and Synset('governor.n.01'):
# my_WUP = 6.67, the given similarity is: 5.25
# Similarity between Synset('murder.n.01') and Synset('manslaughter.n.01'):
# my_WUP = 9.17, the given similarity is: 8.53
# Similarity between Synset('soap.n.02') and Synset('opera.n.01'):
# my_WUP = 2.35, the given similarity is: 7.94
# Similarity between Synset('opera.n.03') and Synset('operation.n.08'):
# my_WUP = 3.08, the given similarity is: 6.88
# Similarity between Synset('biography.n.01') and Synset('moral.n.01'):
# my_WUP = 4.29, the given similarity is: 5.94
# Similarity between Synset('stress.n.03') and Synset('animation.n.01'):
# my_WUP = 5.33, the given similarity is: 4.06
# Similarity between Synset('output.n.04') and Synset('crowd.n.02'):
# my_WUP = 3.64, the given similarity is: 6.25
# Similarity between Synset('television.n.01') and Synset('film.n.02'):
# my_WUP = 7.78, the given similarity is: 7.72
# Similarity between Synset('lover.n.01') and Synset('quarrel.n.02'):
# my_WUP = 4.0, the given similarity is: 6.19
# Similarity between Synset('viewer.n.02') and Synset('series.n.03'):
# my_WUP = 5.0, the given similarity is: 2.97
# Similarity between Synset('possibility.n.02') and Synset('girlfriend.n.02'):
# my_WUP = 1.67, the given similarity is: 1.94
# Similarity between Synset('population.n.05') and Synset('development.n.01'):
# my_WUP = 7.27, the given similarity is: 3.75
# Similarity between Synset('morality.n.01') and Synset('importance.n.01'):
# my_WUP = 6.67, the given similarity is: 3.31
# Similarity between Synset('morality.n.01') and Synset('marriage.n.04'):
# my_WUP = 5.45, the given similarity is: 3.69
# Similarity between Synset('mexico.n.01') and Synset('brazil.n.01'):
# my_WUP = 8.0, the given similarity is: 7.44
# Similarity between Synset('sex.n.04') and Synset('equality.n.02'):
# my_WUP = 4.62, the given similarity is: 6.41
# Similarity between Synset('change.n.02') and Synset('attitude.n.04'):
# my_WUP = 5.45, the given similarity is: 5.44
# Similarity between Synset('class.n.01') and Synset('planning.n.03'):
# my_WUP = 3.08, the given similarity is: 6.25
# Similarity between Synset('opera.n.01') and Synset('diligence.n.02'):
# my_WUP = 2.86, the given similarity is: 2.63
# Similarity between Synset('carbohydrate.n.01') and Synset('access.n.03'):
# my_WUP = 2.86, the given similarity is: 0.88
# Similarity between Synset('practice.n.05') and Synset('institution.n.03'):
# my_WUP = 8.33, the given similarity is: 3.19
# Similarity between Synset('ministry.n.01') and Synset('culture.n.01'):
# my_WUP = 5.33, the given similarity is: 4.69
# Similarity between Synset('problem.n.01') and Synset('challenge.n.01'):
# my_WUP = 6.15, the given similarity is: 6.75
# Similarity between Synset('size.n.04') and Synset('prominence.n.01'):
# my_WUP = 6.15, the given similarity is: 5.31
# Similarity between Synset('area.n.01') and Synset('citizen.n.01'):
# my_WUP = 4.0, the given similarity is: 7.31
# Similarity between Synset('satellite.n.02') and Synset('multitude.n.03'):
# my_WUP = 2.0, the given similarity is: 5.75
# Similarity between Synset('exploitation.n.01') and Synset('issue.n.04'):
# my_WUP = 7.5, the given similarity is: 3.97
# Similarity between Synset('experience.n.03') and Synset('music.n.03'):
# my_WUP = 6.15, the given similarity is: 3.47
# Similarity between Synset('music.n.03') and Synset('undertaking.n.01'):
# my_WUP = 8.0, the given similarity is: 3.63
# Similarity between Synset('glass.n.01') and Synset('alloy.n.01'):
# my_WUP = 5.45, the given similarity is: 5.56
# Similarity between Synset('aluminum.n.01') and Synset('metallic_element.n.01'):
# my_WUP = 9.23, the given similarity is: 7.83
# Similarity between Synset('opportunity.n.01') and Synset('credibility.n.01'):
# my_WUP = 5.0, the given similarity is: 3.88
# Similarity between Synset('exhibit.n.01') and Synset('memorabilia.n.01'):
# my_WUP = 4.29, the given similarity is: 5.31
# Similarity between Synset('concert.n.01') and Synset('ace.n.03'):
# my_WUP = 1.43, the given similarity is: 6.81
# Similarity between Synset('rock_'n'_roll.n.01') and Synset('jazz.n.02'):
# my_WUP = 8.57, the given similarity is: 7.59
# Similarity between Synset('museum.n.01') and Synset('theater.n.01'):
# my_WUP = 6.25, the given similarity is: 7.19
# Similarity between Synset('observation.n.01') and Synset('architecture.n.03'):
# my_WUP = 7.06, the given similarity is: 4.38
# Similarity between Synset('quad.n.03') and Synset('universe.n.01'):
# my_WUP = 5.71, the given similarity is: 6.53
# Similarity between Synset('preservation.n.02') and Synset('worldly_concern.n.01'):
# my_WUP = 5.88, the given similarity is: 6.19
# Similarity between Synset('admission.n.02') and Synset('slate.n.04'):
# my_WUP = 5.71, the given similarity is: 7.69
# Similarity between Synset('shower.n.03') and Synset('thunderstorm.n.01'):
# my_WUP = 7.0, the given similarity is: 6.31
# Similarity between Synset('shower.n.02') and Synset('flood.n.05'):
# my_WUP = 6.36, the given similarity is: 6.03
# Similarity between Synset('weather.n.01') and Synset('prognosis.n.01'):
# my_WUP = 1.33, the given similarity is: 8.34
# Similarity between Synset('catastrophe.n.02') and Synset('sphere.n.01'):
# my_WUP = 5.0, the given similarity is: 6.25
# Similarity between Synset('governor.n.02') and Synset('office.n.01'):
# my_WUP = 5.26, the given similarity is: 6.34
# Similarity between Synset('computer_architecture.n.02') and Synset('century.n.01'):
# my_WUP = 3.08, the given similarity is: 3.78

# %% [markdown]
# ## Shortest Path

# %% [markdown]
# Define the maximum distance in WordNet tree

# %%
def max_path():
    """
    Returns:
        The max depth of WordNet tree (20)
    """
    max_path = 0
    for synset in wn.all_synsets():
        if synset.max_depth() > max_path:
            max_path = synset.max_depth()
    return max_path

def max_path_2(): #19
    return max(max(len(hyp_path) for hyp_path in ss.hypernym_paths()) for ss in wn.all_synsets())

# max_depth = max_path() #! take too much time to compute
max_depth = 20

# %% [markdown]
# Define the distence method between two words in WordNet, for doing that we define a
# function that evaluate the lowest_common_subsumer, but without using the built-in function
# *lowest_common_hypernyms* of wordnet.
#
# We also use *hypenym_paths* function that return all the tree paths between the root and
# the given synset.

# %%
def syn_distance(synset1, synset2):
    '''
    Args:
        synset1: first synset to calculate distance
        synset2: second synset to calculate
    Returns:
        distance between the two synset
    '''
    lcs = lowest_common_subsumer(synset1, synset2)
    if lcs is None:
        return None

    hypernym1 = synset1.hypernym_paths()
    hypernym2 = synset2.hypernym_paths()

    # paths from LCS to root
    hypernym_lcs = lcs.hypernym_paths()

    # create a set of unique items flattening the nested list
    set_lcs = set(deepflatten(hypernym_lcs))

    # remove root
    set_lcs.remove(lcs)

    # path from synset to LCS
    hypernym1 = list(map(lambda x: [y for y in x if y not in set_lcs], hypernym1))
    hypernym2 = list(map(lambda x: [y for y in x if y not in set_lcs], hypernym2))

    # path containing LCS
    hypernym1 = list(filter(lambda x: lcs in x, hypernym1))
    hypernym2 = list(filter(lambda x: lcs in x, hypernym2))

    return min(list(map(lambda x: len(x), hypernym1))) + min(list(map(lambda x: len(x), hypernym2))) - 2

def sim_path(syn1, syn2):
    '''
    Args:
        synset1: first synset
        synset2: second synset
    Returns:
        Shortest Path Similarity between the two synset 
        with normalization from [0, 2 * max_depth] to [0,10]:
        new_val = (val - lower_bound)/(upper_bound - lower_bound)
        = (x - 0)/(2 * max_depth - 0) = x / 40
        --> Divide by 40 (max_depth * 2) wich is the max possible value
    '''
    len = syn_distance(syn1, syn2)
    if(len is None):
        return 0
    return round(((2 * max_depth - len) / 40)* 10, 2)

# %% [markdown]
# ### Print result

# %%
print_result(sim_path)
# Out:
# sim_path = 9.75  	given: 6.77 	Differnce --> 2.98
# sim_path = 9.75  	given: 7.35 	Differnce --> 2.4
# sim_path = 10.0  	given: 10.00 	Differnce --> 0.0
# sim_path = 9.5  	given: 7.46 	Differnce --> 2.04
# sim_path = 9.25  	given: 7.62 	Differnce --> 1.63
# sim_path = 8.25  	given: 7.58 	Differnce --> 0.67
# sim_path = 8.5  	given: 5.77 	Differnce --> 2.73
# sim_path = 8.75  	given: 6.31 	Differnce --> 2.44
# sim_path = 7.5  	given: 7.50 	Differnce --> 0.0
# sim_path = 9.5  	given: 6.77 	Differnce --> 2.73
# sim_path = 9.25  	given: 7.42 	Differnce --> 1.83
# sim_path = 7.75  	given: 6.85 	Differnce --> 0.9
# sim_path = 9.5  	given: 6.19 	Differnce --> 3.31
# sim_path = 9.25  	given: 5.92 	Differnce --> 3.33
# sim_path = 9.5  	given: 7.00 	Differnce --> 2.5
# sim_path = 8.5  	given: 6.62 	Differnce --> 1.88
# sim_path = 8.25  	given: 6.81 	Differnce --> 1.44
# sim_path = 6.75  	given: 4.62 	Differnce --> 2.13
# sim_path = 6.75  	given: 5.81 	Differnce --> 0.94
# sim_path = 8.75  	given: 7.08 	Differnce --> 1.67
# sim_path = 8.5  	given: 8.08 	Differnce --> 0.42
# sim_path = 8.5  	given: 1.62 	Differnce --> 6.88
# sim_path = 8.75  	given: 1.31 	Differnce --> 7.44
# sim_path = 8.75  	given: 0.92 	Differnce --> 7.83
# sim_path = 8.5  	given: 1.81 	Differnce --> 6.69
# sim_path = 7.25  	given: 6.69 	Differnce --> 0.56
# sim_path = 8.75  	given: 3.73 	Differnce --> 5.02
# sim_path = 8.75  	given: 0.92 	Differnce --> 7.83
# sim_path = 9.5  	given: 7.46 	Differnce --> 2.04
# sim_path = 8.5  	given: 8.12 	Differnce --> 0.38
# sim_path = 10.0  	given: 7.73 	Differnce --> 2.27
# sim_path = 9.5  	given: 9.15 	Differnce --> 0.35
# sim_path = 7.0  	given: 0.31 	Differnce --> 6.69
# sim_path = 7.75  	given: 0.23 	Differnce --> 7.52
# sim_path = 10.0  	given: 8.58 	Differnce --> 1.42
# sim_path = 9.5  	given: 5.92 	Differnce --> 3.58
# sim_path = 9.0  	given: 6.69 	Differnce --> 2.31
# sim_path = 8.5  	given: 8.46 	Differnce --> 0.04
# sim_path = 6.0  	given: 7.65 	Differnce --> 1.65
# sim_path = 7.75  	given: 1.62 	Differnce --> 6.13
# sim_path = 9.5  	given: 9.44 	Differnce --> 0.06
# sim_path = 9.75  	given: 9.03 	Differnce --> 0.72
# sim_path = 9.5  	given: 6.81 	Differnce --> 2.69
# sim_path = 8.75  	given: 6.63 	Differnce --> 2.12
# sim_path = 8.0  	given: 7.56 	Differnce --> 0.44
# sim_path = 7.0  	given: 6.73 	Differnce --> 0.27
# sim_path = 8.75  	given: 7.65 	Differnce --> 1.1
# sim_path = 9.25  	given: 2.50 	Differnce --> 6.75
# sim_path = 7.5  	given: 8.38 	Differnce --> 0.88
# sim_path = 8.25  	given: 7.38 	Differnce --> 0.87
# sim_path = 6.75  	given: 6.19 	Differnce --> 0.56
# sim_path = 7.5  	given: 6.73 	Differnce --> 0.77
# sim_path = 8.5  	given: 7.92 	Differnce --> 0.58
# sim_path = 6.5  	given: 8.12 	Differnce --> 1.62
# sim_path = 9.5  	given: 7.35 	Differnce --> 2.15
# sim_path = 8.75  	given: 4.88 	Differnce --> 3.87
# sim_path = 9.0  	given: 5.54 	Differnce --> 3.46
# sim_path = 9.5  	given: 8.46 	Differnce --> 1.04
# sim_path = 9.5  	given: 8.13 	Differnce --> 1.37
# sim_path = 7.5  	given: 3.04 	Differnce --> 4.46
# sim_path = 8.25  	given: 1.31 	Differnce --> 6.94
# sim_path = 8.5  	given: 5.96 	Differnce --> 2.54
# sim_path = 9.5  	given: 6.87 	Differnce --> 2.63
# sim_path = 9.0  	given: 7.85 	Differnce --> 1.15
# sim_path = 8.75  	given: 2.65 	Differnce --> 6.1
# sim_path = 10.0  	given: 8.94 	Differnce --> 1.06
# sim_path = 10.0  	given: 8.96 	Differnce --> 1.04
# sim_path = 9.75  	given: 9.29 	Differnce --> 0.46
# sim_path = 9.75  	given: 8.83 	Differnce --> 0.92
# sim_path = 9.75  	given: 9.10 	Differnce --> 0.65
# sim_path = 9.75  	given: 8.87 	Differnce --> 0.88
# sim_path = 10.0  	given: 9.02 	Differnce --> 0.98
# sim_path = 10.0  	given: 9.29 	Differnce --> 0.71
# sim_path = 7.75  	given: 8.79 	Differnce --> 1.04
# sim_path = 7.75  	given: 7.52 	Differnce --> 0.23
# sim_path = 9.75  	given: 7.10 	Differnce --> 2.65
# sim_path = 9.25  	given: 7.38 	Differnce --> 1.87
# sim_path = 9.75  	given: 6.46 	Differnce --> 3.29
# sim_path = 9.75  	given: 6.27 	Differnce --> 3.48
# sim_path = 9.0  	given: 2.69 	Differnce --> 6.31
# sim_path = 9.0  	given: 4.46 	Differnce --> 4.54
# sim_path = 5.75  	given: 5.85 	Differnce --> 0.1
# sim_path = 8.25  	given: 5.00 	Differnce --> 3.25
# sim_path = 8.0  	given: 2.08 	Differnce --> 5.92
# sim_path = 6.25  	given: 4.42 	Differnce --> 1.83
# sim_path = 9.0  	given: 4.38 	Differnce --> 4.62
# sim_path = 8.0  	given: 1.85 	Differnce --> 6.15
# sim_path = 9.0  	given: 3.08 	Differnce --> 5.92
# sim_path = 9.0  	given: 0.92 	Differnce --> 8.08
# sim_path = 8.75  	given: 3.15 	Differnce --> 5.6
# sim_path = 9.0  	given: 0.92 	Differnce --> 8.08
# sim_path = 7.5  	given: 0.54 	Differnce --> 6.96
# sim_path = 8.25  	given: 2.08 	Differnce --> 6.17
# sim_path = 7.25  	given: 0.54 	Differnce --> 6.71
# sim_path = 4.25  	given: 0.62 	Differnce --> 3.63
# sim_path = 9.0  	given: 8.42 	Differnce --> 0.58
# sim_path = 9.5  	given: 9.08 	Differnce --> 0.42
# sim_path = 9.75  	given: 9.04 	Differnce --> 0.71
# sim_path = 9.75  	given: 8.27 	Differnce --> 1.48
# sim_path = 9.5  	given: 7.57 	Differnce --> 1.93
# sim_path = 9.25  	given: 7.29 	Differnce --> 1.96
# sim_path = 8.5  	given: 8.50 	Differnce --> 0.0
# sim_path = 9.5  	given: 7.73 	Differnce --> 1.77
# sim_path = 7.5  	given: 6.88 	Differnce --> 0.62
# sim_path = 7.0  	given: 5.65 	Differnce --> 1.35
# sim_path = 8.0  	given: 3.31 	Differnce --> 4.69
# sim_path = 9.5  	given: 8.00 	Differnce --> 1.5
# sim_path = 9.5  	given: 8.00 	Differnce --> 1.5
# sim_path = 9.25  	given: 7.08 	Differnce --> 2.17
# sim_path = 8.75  	given: 6.85 	Differnce --> 1.9
# sim_path = 9.25  	given: 7.00 	Differnce --> 2.25
# sim_path = 9.5  	given: 4.77 	Differnce --> 4.73
# sim_path = 9.25  	given: 5.62 	Differnce --> 3.63
# sim_path = 8.25  	given: 5.87 	Differnce --> 2.38
# sim_path = 8.5  	given: 8.08 	Differnce --> 0.42
# sim_path = 7.0  	given: 7.00 	Differnce --> 0.0
# sim_path = 7.0  	given: 6.85 	Differnce --> 0.15
# sim_path = 7.25  	given: 7.42 	Differnce --> 0.17
# sim_path = 6.75  	given: 6.58 	Differnce --> 0.17
# sim_path = 7.0  	given: 6.42 	Differnce --> 0.58
# sim_path = 5.25  	given: 8.21 	Differnce --> 2.96
# sim_path = 8.5  	given: 7.69 	Differnce --> 0.81
# sim_path = 7.25  	given: 7.23 	Differnce --> 0.02
# sim_path = 9.75  	given: 6.71 	Differnce --> 3.04
# sim_path = 9.5  	given: 5.58 	Differnce --> 3.92
# sim_path = 8.75  	given: 7.48 	Differnce --> 1.27
# sim_path = 9.5  	given: 8.45 	Differnce --> 1.05
# sim_path = 9.25  	given: 8.06 	Differnce --> 1.19
# sim_path = 9.25  	given: 8.08 	Differnce --> 1.17
# sim_path = 9.25  	given: 8.02 	Differnce --> 1.23
# sim_path = 8.25  	given: 8.11 	Differnce --> 0.14
# sim_path = 8.5  	given: 7.92 	Differnce --> 0.58
# sim_path = 8.75  	given: 7.94 	Differnce --> 0.81
# sim_path = 9.75  	given: 5.85 	Differnce --> 3.9
# sim_path = 9.5  	given: 3.85 	Differnce --> 5.65
# sim_path = 9.25  	given: 2.81 	Differnce --> 6.44
# sim_path = 9.75  	given: 6.65 	Differnce --> 3.1
# sim_path = 9.5  	given: 2.50 	Differnce --> 7.0
# sim_path = 9.25  	given: 1.77 	Differnce --> 7.48
# sim_path = 8.75  	given: 6.04 	Differnce --> 2.71
# sim_path = 8.75  	given: 6.58 	Differnce --> 2.17
# sim_path = 9.5  	given: 6.85 	Differnce --> 2.65
# sim_path = 9.0  	given: 2.40 	Differnce --> 6.6
# sim_path = 9.25  	given: 2.92 	Differnce --> 6.33
# sim_path = 8.75  	given: 3.69 	Differnce --> 5.06
# sim_path = 8.75  	given: 2.15 	Differnce --> 6.6
# sim_path = 9.0  	given: 7.25 	Differnce --> 1.75
# sim_path = 8.75  	given: 5.00 	Differnce --> 3.75
# sim_path = 8.5  	given: 1.92 	Differnce --> 6.58
# sim_path = 8.75  	given: 5.90 	Differnce --> 2.85
# sim_path = 9.75  	given: 7.42 	Differnce --> 2.33
# sim_path = 6.0  	given: 7.27 	Differnce --> 1.27
# sim_path = 7.5  	given: 1.81 	Differnce --> 5.69
# sim_path = 6.75  	given: 5.06 	Differnce --> 1.69
# sim_path = 7.75  	given: 5.09 	Differnce --> 2.66
# sim_path = 7.75  	given: 6.78 	Differnce --> 0.97
# sim_path = 7.5  	given: 6.06 	Differnce --> 1.44
# sim_path = 7.0  	given: 6.94 	Differnce --> 0.06
# sim_path = 6.5  	given: 8.31 	Differnce --> 1.81
# sim_path = 9.25  	given: 4.59 	Differnce --> 4.66
# sim_path = 9.0  	given: 2.94 	Differnce --> 6.06
# sim_path = 7.75  	given: 5.63 	Differnce --> 2.12
# sim_path = 9.75  	given: 8.16 	Differnce --> 1.59
# sim_path = 7.25  	given: 7.53 	Differnce --> 0.28
# sim_path = 9.0  	given: 4.56 	Differnce --> 4.44
# sim_path = 8.5  	given: 6.34 	Differnce --> 2.16
# sim_path = 7.25  	given: 6.56 	Differnce --> 0.69
# sim_path = 9.5  	given: 2.38 	Differnce --> 7.12
# sim_path = 7.25  	given: 2.22 	Differnce --> 5.03
# sim_path = 9.25  	given: 8.66 	Differnce --> 0.59
# sim_path = 7.5  	given: 4.47 	Differnce --> 3.03
# sim_path = 8.75  	given: 5.34 	Differnce --> 3.41
# sim_path = 8.0  	given: 3.69 	Differnce --> 4.31
# sim_path = 7.0  	given: 3.00 	Differnce --> 4.0
# sim_path = 7.75  	given: 8.13 	Differnce --> 0.38
# sim_path = 9.75  	given: 6.31 	Differnce --> 3.44
# sim_path = 8.75  	given: 6.22 	Differnce --> 2.53
# sim_path = 9.25  	given: 6.50 	Differnce --> 2.75
# sim_path = 8.5  	given: 3.91 	Differnce --> 4.59
# sim_path = 7.25  	given: 2.56 	Differnce --> 4.69
# sim_path = 8.75  	given: 3.00 	Differnce --> 5.75
# sim_path = 7.25  	given: 5.63 	Differnce --> 1.62
# sim_path = 9.5  	given: 7.59 	Differnce --> 1.91
# sim_path = 8.25  	given: 3.16 	Differnce --> 5.09
# sim_path = 8.5  	given: 1.19 	Differnce --> 7.31
# sim_path = 8.25  	given: 3.31 	Differnce --> 4.94
# sim_path = 8.75  	given: 6.63 	Differnce --> 2.12
# sim_path = 7.75  	given: 4.75 	Differnce --> 3.0
# sim_path = 8.75  	given: 3.69 	Differnce --> 5.06
# sim_path = 7.75  	given: 4.25 	Differnce --> 3.5
# sim_path = 8.5  	given: 6.56 	Differnce --> 1.94
# sim_path = 9.0  	given: 4.25 	Differnce --> 4.75
# sim_path = 9.0  	given: 5.88 	Differnce --> 3.12
# sim_path = 8.5  	given: 5.94 	Differnce --> 2.56
# sim_path = 9.0  	given: 7.56 	Differnce --> 1.44
# sim_path = 7.75  	given: 2.75 	Differnce --> 5.0
# sim_path = 7.5  	given: 7.03 	Differnce --> 0.47
# sim_path = 8.25  	given: 5.47 	Differnce --> 2.78
# sim_path = 7.75  	given: 6.47 	Differnce --> 1.28
# sim_path = 9.25  	given: 7.91 	Differnce --> 1.34
# sim_path = 8.5  	given: 4.97 	Differnce --> 3.53
# sim_path = 7.25  	given: 5.00 	Differnce --> 2.25
# sim_path = 7.25  	given: 5.19 	Differnce --> 2.06
# sim_path = 8.5  	given: 7.03 	Differnce --> 1.47
# sim_path = 9.5  	given: 3.44 	Differnce --> 6.06
# sim_path = 8.0  	given: 2.31 	Differnce --> 5.69
# sim_path = 8.25  	given: 5.91 	Differnce --> 2.34
# sim_path = 7.0  	given: 7.38 	Differnce --> 0.38
# sim_path = 9.5  	given: 8.13 	Differnce --> 1.37
# sim_path = 7.25  	given: 4.63 	Differnce --> 2.62
# sim_path = 8.25  	given: 5.25 	Differnce --> 3.0
# sim_path = 7.5  	given: 5.03 	Differnce --> 2.47
# sim_path = 7.5  	given: 6.69 	Differnce --> 0.81
# sim_path = 9.5  	given: 7.88 	Differnce --> 1.62
# sim_path = 9.5  	given: 4.50 	Differnce --> 5.0
# sim_path = 8.0  	given: 4.75 	Differnce --> 3.25
# sim_path = 7.25  	given: 4.47 	Differnce --> 2.78
# sim_path = 6.75  	given: 3.25 	Differnce --> 3.5
# sim_path = 8.5  	given: 5.63 	Differnce --> 2.87
# sim_path = 9.0  	given: 3.69 	Differnce --> 5.31
# sim_path = 9.25  	given: 2.94 	Differnce --> 6.31
# sim_path = 7.0  	given: 5.28 	Differnce --> 1.72
# sim_path = 8.75  	given: 5.00 	Differnce --> 3.75
# sim_path = 8.25  	given: 6.44 	Differnce --> 1.81
# sim_path = 7.25  	given: 4.13 	Differnce --> 3.12
# sim_path = 7.75  	given: 4.75 	Differnce --> 3.0
# sim_path = 6.75  	given: 2.38 	Differnce --> 4.37
# sim_path = 8.25  	given: 4.94 	Differnce --> 3.31
# sim_path = 8.75  	given: 8.06 	Differnce --> 0.69
# sim_path = 9.25  	given: 5.31 	Differnce --> 3.94
# sim_path = 7.5  	given: 8.03 	Differnce --> 0.53
# sim_path = 6.75  	given: 5.94 	Differnce --> 0.81
# sim_path = 9.0  	given: 6.00 	Differnce --> 3.0
# sim_path = 8.5  	given: 5.41 	Differnce --> 3.09
# sim_path = 7.25  	given: 1.81 	Differnce --> 5.44
# sim_path = 9.75  	given: 8.97 	Differnce --> 0.78
# sim_path = 7.75  	given: 6.00 	Differnce --> 1.75
# sim_path = 9.25  	given: 6.72 	Differnce --> 2.53
# sim_path = 8.25  	given: 8.00 	Differnce --> 0.25
# sim_path = 8.5  	given: 4.81 	Differnce --> 3.69
# sim_path = 9.25  	given: 3.88 	Differnce --> 5.37
# sim_path = 8.0  	given: 5.16 	Differnce --> 2.84
# sim_path = 8.5  	given: 2.25 	Differnce --> 6.25
# sim_path = 8.75  	given: 6.44 	Differnce --> 2.31
# sim_path = 9.75  	given: 8.88 	Differnce --> 0.87
# sim_path = 8.75  	given: 6.88 	Differnce --> 1.87
# sim_path = 7.75  	given: 4.94 	Differnce --> 2.81
# sim_path = 7.0  	given: 2.56 	Differnce --> 4.44
# sim_path = 8.0  	given: 6.38 	Differnce --> 1.62
# sim_path = 9.5  	given: 7.81 	Differnce --> 1.69
# sim_path = 8.25  	given: 1.75 	Differnce --> 6.5
# sim_path = 9.25  	given: 4.25 	Differnce --> 5.0
# sim_path = 8.5  	given: 3.88 	Differnce --> 4.62
# sim_path = 8.5  	given: 2.88 	Differnce --> 5.62
# sim_path = 9.5  	given: 7.63 	Differnce --> 1.87
# sim_path = 7.5  	given: 6.48 	Differnce --> 1.02
# sim_path = 10.0  	given: 8.44 	Differnce --> 1.56
# sim_path = 7.75  	given: 7.50 	Differnce --> 0.25
# sim_path = 6.5  	given: 8.59 	Differnce --> 2.09
# sim_path = 8.0  	given: 6.34 	Differnce --> 1.66
# sim_path = 8.5  	given: 3.38 	Differnce --> 5.12
# sim_path = 8.75  	given: 6.00 	Differnce --> 2.75
# sim_path = 7.5  	given: 3.88 	Differnce --> 3.62
# sim_path = 8.75  	given: 7.63 	Differnce --> 1.12
# sim_path = 9.25  	given: 7.78 	Differnce --> 1.47
# sim_path = 10.0  	given: 9.22 	Differnce --> 0.78
# sim_path = 7.75  	given: 7.38 	Differnce --> 0.37
# sim_path = 8.0  	given: 6.09 	Differnce --> 1.91
# sim_path = 7.0  	given: 8.50 	Differnce --> 1.5
# sim_path = 9.25  	given: 8.31 	Differnce --> 0.94
# sim_path = 9.5  	given: 7.13 	Differnce --> 2.37
# sim_path = 8.0  	given: 5.91 	Differnce --> 2.09
# sim_path = 6.5  	given: 6.47 	Differnce --> 0.03
# sim_path = 8.25  	given: 3.38 	Differnce --> 4.87
# sim_path = 8.25  	given: 3.63 	Differnce --> 4.62
# sim_path = 0  	given: 7.13 	Differnce --> 7.13
# sim_path = 9.75  	given: 7.89 	Differnce --> 1.86
# sim_path = 6.5  	given: 5.97 	Differnce --> 0.53
# sim_path = 8.5  	given: 7.03 	Differnce --> 1.47
# sim_path = 7.75  	given: 7.69 	Differnce --> 0.06
# sim_path = 7.5  	given: 7.47 	Differnce --> 0.03
# sim_path = 9.5  	given: 6.19 	Differnce --> 3.31
# sim_path = 8.5  	given: 6.97 	Differnce --> 1.53
# sim_path = 8.0  	given: 3.56 	Differnce --> 4.44
# sim_path = 8.25  	given: 7.47 	Differnce --> 0.78
# sim_path = 9.75  	given: 8.34 	Differnce --> 1.41
# sim_path = 9.5  	given: 8.70 	Differnce --> 0.8
# sim_path = 9.25  	given: 7.81 	Differnce --> 1.44
# sim_path = 7.5  	given: 5.70 	Differnce --> 1.8
# sim_path = 8.5  	given: 6.22 	Differnce --> 2.28
# sim_path = 8.0  	given: 6.34 	Differnce --> 1.66
# sim_path = 8.75  	given: 4.06 	Differnce --> 4.69
# sim_path = 9.25  	given: 4.47 	Differnce --> 4.78
# sim_path = 9.5  	given: 5.97 	Differnce --> 3.53
# sim_path = 8.5  	given: 7.61 	Differnce --> 0.89
# sim_path = 9.5  	given: 8.36 	Differnce --> 1.14
# sim_path = 7.5  	given: 7.41 	Differnce --> 0.09
# sim_path = 9.0  	given: 2.69 	Differnce --> 6.31
# sim_path = 9.25  	given: 3.94 	Differnce --> 5.31
# sim_path = 9.25  	given: 7.16 	Differnce --> 2.09
# sim_path = 8.0  	given: 5.63 	Differnce --> 2.37
# sim_path = 9.5  	given: 7.53 	Differnce --> 1.97
# sim_path = 8.75  	given: 8.31 	Differnce --> 0.44
# sim_path = 9.75  	given: 8.81 	Differnce --> 0.94
# sim_path = 9.25  	given: 6.25 	Differnce --> 3.0
# sim_path = 9.5  	given: 8.30 	Differnce --> 1.2
# sim_path = 9.0  	given: 5.25 	Differnce --> 3.75
# sim_path = 9.5  	given: 8.53 	Differnce --> 0.97
# sim_path = 6.75  	given: 7.94 	Differnce --> 1.19
# sim_path = 7.75  	given: 6.88 	Differnce --> 0.87
# sim_path = 8.25  	given: 5.94 	Differnce --> 2.31
# sim_path = 8.5  	given: 4.06 	Differnce --> 4.44
# sim_path = 8.25  	given: 6.25 	Differnce --> 2.0
# sim_path = 9.0  	given: 7.72 	Differnce --> 1.28
# sim_path = 7.0  	given: 6.19 	Differnce --> 0.81
# sim_path = 7.5  	given: 2.97 	Differnce --> 4.53
# sim_path = 7.5  	given: 1.94 	Differnce --> 5.56
# sim_path = 8.5  	given: 3.75 	Differnce --> 4.75
# sim_path = 9.0  	given: 3.31 	Differnce --> 5.69
# sim_path = 8.75  	given: 3.69 	Differnce --> 5.06
# sim_path = 9.0  	given: 7.44 	Differnce --> 1.56
# sim_path = 8.25  	given: 6.41 	Differnce --> 1.84
# sim_path = 8.75  	given: 5.44 	Differnce --> 3.31
# sim_path = 7.75  	given: 6.25 	Differnce --> 1.5
# sim_path = 7.5  	given: 2.63 	Differnce --> 4.87
# sim_path = 7.5  	given: 0.88 	Differnce --> 6.62
# sim_path = 9.5  	given: 3.19 	Differnce --> 6.31
# sim_path = 8.25  	given: 4.69 	Differnce --> 3.56
# sim_path = 8.75  	given: 6.75 	Differnce --> 2.0
# sim_path = 8.75  	given: 5.31 	Differnce --> 3.44
# sim_path = 7.75  	given: 7.31 	Differnce --> 0.44
# sim_path = 8.0  	given: 5.75 	Differnce --> 2.25
# sim_path = 9.25  	given: 3.97 	Differnce --> 5.28
# sim_path = 8.75  	given: 3.47 	Differnce --> 5.28
# sim_path = 9.25  	given: 3.63 	Differnce --> 5.62
# sim_path = 8.75  	given: 5.56 	Differnce --> 3.19
# sim_path = 9.75  	given: 7.83 	Differnce --> 1.92
# sim_path = 8.75  	given: 3.88 	Differnce --> 4.87
# sim_path = 8.0  	given: 5.31 	Differnce --> 2.69
# sim_path = 7.0  	given: 6.81 	Differnce --> 0.19
# sim_path = 9.5  	given: 7.59 	Differnce --> 1.91
# sim_path = 8.5  	given: 7.19 	Differnce --> 1.31
# sim_path = 8.75  	given: 4.38 	Differnce --> 4.37
# sim_path = 9.0  	given: 6.53 	Differnce --> 2.47
# sim_path = 8.5  	given: 6.19 	Differnce --> 2.31
# sim_path = 8.5  	given: 7.69 	Differnce --> 0.81
# sim_path = 8.5  	given: 6.31 	Differnce --> 2.19
# sim_path = 9.0  	given: 6.03 	Differnce --> 2.97
# sim_path = 6.75  	given: 8.34 	Differnce --> 1.59
# sim_path = 8.0  	given: 6.25 	Differnce --> 1.75
# sim_path = 7.75  	given: 6.34 	Differnce --> 1.41
# sim_path = 7.75  	given: 3.78 	Differnce --> 3.97

# %% [markdown]
# ### Save result in a list

# %%
sp_result = sim_res_list(sim_path)

# %% [markdown]
# ## Leacock & Chodorow

# %%
def lec(syn1, syn2):
    '''
    Args:
        synset1: first synset
        synset2: second synset
    Returns:
        Leakcock & Chodorow Similarity between the two synset 
        To avoid log(0) we add 1 to numerator and denominator
    '''
    len = syn_distance(syn1, syn2)
    if len is None:
        return 0
    
    # return round(np.log(len + 1 / 2 * max_depth + 1), 2)
    return round(np.log((2 * max_depth + 1) / (len  + 1)), 2)

# %% [markdown]
# ### Print result

# %%
print_result(lec)
# Out:
# lec = 3.02  	given: 6.77 	Differnce --> 3.75
# lec = 3.02  	given: 7.35 	Differnce --> 4.33
# lec = 3.71  	given: 10.00 	Differnce --> 6.29
# lec = 2.61  	given: 7.46 	Differnce --> 4.85
# lec = 2.33  	given: 7.62 	Differnce --> 5.29
# lec = 1.63  	given: 7.58 	Differnce --> 5.95
# lec = 1.77  	given: 5.77 	Differnce --> 4.0
# lec = 1.92  	given: 6.31 	Differnce --> 4.39
# lec = 1.32  	given: 7.50 	Differnce --> 6.18
# lec = 2.61  	given: 6.77 	Differnce --> 4.16
# lec = 2.33  	given: 7.42 	Differnce --> 5.09
# lec = 1.41  	given: 6.85 	Differnce --> 5.44
# lec = 2.61  	given: 6.19 	Differnce --> 3.58
# lec = 2.33  	given: 5.92 	Differnce --> 3.59
# lec = 2.61  	given: 7.00 	Differnce --> 4.39
# lec = 1.77  	given: 6.62 	Differnce --> 4.85
# lec = 1.63  	given: 6.81 	Differnce --> 5.18
# lec = 1.07  	given: 4.62 	Differnce --> 3.55
# lec = 1.07  	given: 5.81 	Differnce --> 4.74
# lec = 1.92  	given: 7.08 	Differnce --> 5.16
# lec = 1.77  	given: 8.08 	Differnce --> 6.31
# lec = 1.77  	given: 1.62 	Differnce --> 0.15
# lec = 1.92  	given: 1.31 	Differnce --> 0.61
# lec = 1.92  	given: 0.92 	Differnce --> 1.0
# lec = 1.77  	given: 1.81 	Differnce --> 0.04
# lec = 1.23  	given: 6.69 	Differnce --> 5.46
# lec = 1.92  	given: 3.73 	Differnce --> 1.81
# lec = 1.92  	given: 0.92 	Differnce --> 1.0
# lec = 2.61  	given: 7.46 	Differnce --> 4.85
# lec = 1.77  	given: 8.12 	Differnce --> 6.35
# lec = 3.71  	given: 7.73 	Differnce --> 4.02
# lec = 2.61  	given: 9.15 	Differnce --> 6.54
# lec = 1.15  	given: 0.31 	Differnce --> 0.84
# lec = 1.41  	given: 0.23 	Differnce --> 1.18
# lec = 3.71  	given: 8.58 	Differnce --> 4.87
# lec = 2.61  	given: 5.92 	Differnce --> 3.31
# lec = 2.1  	given: 6.69 	Differnce --> 4.59
# lec = 1.77  	given: 8.46 	Differnce --> 6.69
# lec = 0.88  	given: 7.65 	Differnce --> 6.77
# lec = 1.41  	given: 1.62 	Differnce --> 0.21
# lec = 2.61  	given: 9.44 	Differnce --> 6.83
# lec = 3.02  	given: 9.03 	Differnce --> 6.01
# lec = 2.61  	given: 6.81 	Differnce --> 4.2
# lec = 1.92  	given: 6.63 	Differnce --> 4.71
# lec = 1.52  	given: 7.56 	Differnce --> 6.04
# lec = 1.15  	given: 6.73 	Differnce --> 5.58
# lec = 1.92  	given: 7.65 	Differnce --> 5.73
# lec = 2.33  	given: 2.50 	Differnce --> 0.17
# lec = 1.32  	given: 8.38 	Differnce --> 7.06
# lec = 1.63  	given: 7.38 	Differnce --> 5.75
# lec = 1.07  	given: 6.19 	Differnce --> 5.12
# lec = 1.32  	given: 6.73 	Differnce --> 5.41
# lec = 1.77  	given: 7.92 	Differnce --> 6.15
# lec = 1.01  	given: 8.12 	Differnce --> 7.11
# lec = 2.61  	given: 7.35 	Differnce --> 4.74
# lec = 1.92  	given: 4.88 	Differnce --> 2.96
# lec = 2.1  	given: 5.54 	Differnce --> 3.44
# lec = 2.61  	given: 8.46 	Differnce --> 5.85
# lec = 2.61  	given: 8.13 	Differnce --> 5.52
# lec = 1.32  	given: 3.04 	Differnce --> 1.72
# lec = 1.63  	given: 1.31 	Differnce --> 0.32
# lec = 1.77  	given: 5.96 	Differnce --> 4.19
# lec = 2.61  	given: 6.87 	Differnce --> 4.26
# lec = 2.1  	given: 7.85 	Differnce --> 5.75
# lec = 1.92  	given: 2.65 	Differnce --> 0.73
# lec = 3.71  	given: 8.94 	Differnce --> 5.23
# lec = 3.71  	given: 8.96 	Differnce --> 5.25
# lec = 3.02  	given: 9.29 	Differnce --> 6.27
# lec = 3.02  	given: 8.83 	Differnce --> 5.81
# lec = 3.02  	given: 9.10 	Differnce --> 6.08
# lec = 3.02  	given: 8.87 	Differnce --> 5.85
# lec = 3.71  	given: 9.02 	Differnce --> 5.31
# lec = 3.71  	given: 9.29 	Differnce --> 5.58
# lec = 1.41  	given: 8.79 	Differnce --> 7.38
# lec = 1.41  	given: 7.52 	Differnce --> 6.11
# lec = 3.02  	given: 7.10 	Differnce --> 4.08
# lec = 2.33  	given: 7.38 	Differnce --> 5.05
# lec = 3.02  	given: 6.46 	Differnce --> 3.44
# lec = 3.02  	given: 6.27 	Differnce --> 3.25
# lec = 2.1  	given: 2.69 	Differnce --> 0.59
# lec = 2.1  	given: 4.46 	Differnce --> 2.36
# lec = 0.82  	given: 5.85 	Differnce --> 5.03
# lec = 1.63  	given: 5.00 	Differnce --> 3.37
# lec = 1.52  	given: 2.08 	Differnce --> 0.56
# lec = 0.94  	given: 4.42 	Differnce --> 3.48
# lec = 2.1  	given: 4.38 	Differnce --> 2.28
# lec = 1.52  	given: 1.85 	Differnce --> 0.33
# lec = 2.1  	given: 3.08 	Differnce --> 0.98
# lec = 2.1  	given: 0.92 	Differnce --> 1.18
# lec = 1.92  	given: 3.15 	Differnce --> 1.23
# lec = 2.1  	given: 0.92 	Differnce --> 1.18
# lec = 1.32  	given: 0.54 	Differnce --> 0.78
# lec = 1.63  	given: 2.08 	Differnce --> 0.45
# lec = 1.23  	given: 0.54 	Differnce --> 0.69
# lec = 0.54  	given: 0.62 	Differnce --> 0.08
# lec = 2.1  	given: 8.42 	Differnce --> 6.32
# lec = 2.61  	given: 9.08 	Differnce --> 6.47
# lec = 3.02  	given: 9.04 	Differnce --> 6.02
# lec = 3.02  	given: 8.27 	Differnce --> 5.25
# lec = 2.61  	given: 7.57 	Differnce --> 4.96
# lec = 2.33  	given: 7.29 	Differnce --> 4.96
# lec = 1.77  	given: 8.50 	Differnce --> 6.73
# lec = 2.61  	given: 7.73 	Differnce --> 5.12
# lec = 1.32  	given: 6.88 	Differnce --> 5.56
# lec = 1.15  	given: 5.65 	Differnce --> 4.5
# lec = 1.52  	given: 3.31 	Differnce --> 1.79
# lec = 2.61  	given: 8.00 	Differnce --> 5.39
# lec = 2.61  	given: 8.00 	Differnce --> 5.39
# lec = 2.33  	given: 7.08 	Differnce --> 4.75
# lec = 1.92  	given: 6.85 	Differnce --> 4.93
# lec = 2.33  	given: 7.00 	Differnce --> 4.67
# lec = 2.61  	given: 4.77 	Differnce --> 2.16
# lec = 2.33  	given: 5.62 	Differnce --> 3.29
# lec = 1.63  	given: 5.87 	Differnce --> 4.24
# lec = 1.77  	given: 8.08 	Differnce --> 6.31
# lec = 1.15  	given: 7.00 	Differnce --> 5.85
# lec = 1.15  	given: 6.85 	Differnce --> 5.7
# lec = 1.23  	given: 7.42 	Differnce --> 6.19
# lec = 1.07  	given: 6.58 	Differnce --> 5.51
# lec = 1.15  	given: 6.42 	Differnce --> 5.27
# lec = 0.72  	given: 8.21 	Differnce --> 7.49
# lec = 1.77  	given: 7.69 	Differnce --> 5.92
# lec = 1.23  	given: 7.23 	Differnce --> 6.0
# lec = 3.02  	given: 6.71 	Differnce --> 3.69
# lec = 2.61  	given: 5.58 	Differnce --> 2.97
# lec = 1.92  	given: 7.48 	Differnce --> 5.56
# lec = 2.61  	given: 8.45 	Differnce --> 5.84
# lec = 2.33  	given: 8.06 	Differnce --> 5.73
# lec = 2.33  	given: 8.08 	Differnce --> 5.75
# lec = 2.33  	given: 8.02 	Differnce --> 5.69
# lec = 1.63  	given: 8.11 	Differnce --> 6.48
# lec = 1.77  	given: 7.92 	Differnce --> 6.15
# lec = 1.92  	given: 7.94 	Differnce --> 6.02
# lec = 3.02  	given: 5.85 	Differnce --> 2.83
# lec = 2.61  	given: 3.85 	Differnce --> 1.24
# lec = 2.33  	given: 2.81 	Differnce --> 0.48
# lec = 3.02  	given: 6.65 	Differnce --> 3.63
# lec = 2.61  	given: 2.50 	Differnce --> 0.11
# lec = 2.33  	given: 1.77 	Differnce --> 0.56
# lec = 1.92  	given: 6.04 	Differnce --> 4.12
# lec = 1.92  	given: 6.58 	Differnce --> 4.66
# lec = 2.61  	given: 6.85 	Differnce --> 4.24
# lec = 2.1  	given: 2.40 	Differnce --> 0.3
# lec = 2.33  	given: 2.92 	Differnce --> 0.59
# lec = 1.92  	given: 3.69 	Differnce --> 1.77
# lec = 1.92  	given: 2.15 	Differnce --> 0.23
# lec = 2.1  	given: 7.25 	Differnce --> 5.15
# lec = 1.92  	given: 5.00 	Differnce --> 3.08
# lec = 1.77  	given: 1.92 	Differnce --> 0.15
# lec = 1.92  	given: 5.90 	Differnce --> 3.98
# lec = 3.02  	given: 7.42 	Differnce --> 4.4
# lec = 0.88  	given: 7.27 	Differnce --> 6.39
# lec = 1.32  	given: 1.81 	Differnce --> 0.49
# lec = 1.07  	given: 5.06 	Differnce --> 3.99
# lec = 1.41  	given: 5.09 	Differnce --> 3.68
# lec = 1.41  	given: 6.78 	Differnce --> 5.37
# lec = 1.32  	given: 6.06 	Differnce --> 4.74
# lec = 1.15  	given: 6.94 	Differnce --> 5.79
# lec = 1.01  	given: 8.31 	Differnce --> 7.3
# lec = 2.33  	given: 4.59 	Differnce --> 2.26
# lec = 2.1  	given: 2.94 	Differnce --> 0.84
# lec = 1.41  	given: 5.63 	Differnce --> 4.22
# lec = 3.02  	given: 8.16 	Differnce --> 5.14
# lec = 1.23  	given: 7.53 	Differnce --> 6.3
# lec = 2.1  	given: 4.56 	Differnce --> 2.46
# lec = 1.77  	given: 6.34 	Differnce --> 4.57
# lec = 1.23  	given: 6.56 	Differnce --> 5.33
# lec = 2.61  	given: 2.38 	Differnce --> 0.23
# lec = 1.23  	given: 2.22 	Differnce --> 0.99
# lec = 2.33  	given: 8.66 	Differnce --> 6.33
# lec = 1.32  	given: 4.47 	Differnce --> 3.15
# lec = 1.92  	given: 5.34 	Differnce --> 3.42
# lec = 1.52  	given: 3.69 	Differnce --> 2.17
# lec = 1.15  	given: 3.00 	Differnce --> 1.85
# lec = 1.41  	given: 8.13 	Differnce --> 6.72
# lec = 3.02  	given: 6.31 	Differnce --> 3.29
# lec = 1.92  	given: 6.22 	Differnce --> 4.3
# lec = 2.33  	given: 6.50 	Differnce --> 4.17
# lec = 1.77  	given: 3.91 	Differnce --> 2.14
# lec = 1.23  	given: 2.56 	Differnce --> 1.33
# lec = 1.92  	given: 3.00 	Differnce --> 1.08
# lec = 1.23  	given: 5.63 	Differnce --> 4.4
# lec = 2.61  	given: 7.59 	Differnce --> 4.98
# lec = 1.63  	given: 3.16 	Differnce --> 1.53
# lec = 1.77  	given: 1.19 	Differnce --> 0.58
# lec = 1.63  	given: 3.31 	Differnce --> 1.68
# lec = 1.92  	given: 6.63 	Differnce --> 4.71
# lec = 1.41  	given: 4.75 	Differnce --> 3.34
# lec = 1.92  	given: 3.69 	Differnce --> 1.77
# lec = 1.41  	given: 4.25 	Differnce --> 2.84
# lec = 1.77  	given: 6.56 	Differnce --> 4.79
# lec = 2.1  	given: 4.25 	Differnce --> 2.15
# lec = 2.1  	given: 5.88 	Differnce --> 3.78
# lec = 1.77  	given: 5.94 	Differnce --> 4.17
# lec = 2.1  	given: 7.56 	Differnce --> 5.46
# lec = 1.41  	given: 2.75 	Differnce --> 1.34
# lec = 1.32  	given: 7.03 	Differnce --> 5.71
# lec = 1.63  	given: 5.47 	Differnce --> 3.84
# lec = 1.41  	given: 6.47 	Differnce --> 5.06
# lec = 2.33  	given: 7.91 	Differnce --> 5.58
# lec = 1.77  	given: 4.97 	Differnce --> 3.2
# lec = 1.23  	given: 5.00 	Differnce --> 3.77
# lec = 1.23  	given: 5.19 	Differnce --> 3.96
# lec = 1.77  	given: 7.03 	Differnce --> 5.26
# lec = 2.61  	given: 3.44 	Differnce --> 0.83
# lec = 1.52  	given: 2.31 	Differnce --> 0.79
# lec = 1.63  	given: 5.91 	Differnce --> 4.28
# lec = 1.15  	given: 7.38 	Differnce --> 6.23
# lec = 2.61  	given: 8.13 	Differnce --> 5.52
# lec = 1.23  	given: 4.63 	Differnce --> 3.4
# lec = 1.63  	given: 5.25 	Differnce --> 3.62
# lec = 1.32  	given: 5.03 	Differnce --> 3.71
# lec = 1.32  	given: 6.69 	Differnce --> 5.37
# lec = 2.61  	given: 7.88 	Differnce --> 5.27
# lec = 2.61  	given: 4.50 	Differnce --> 1.89
# lec = 1.52  	given: 4.75 	Differnce --> 3.23
# lec = 1.23  	given: 4.47 	Differnce --> 3.24
# lec = 1.07  	given: 3.25 	Differnce --> 2.18
# lec = 1.77  	given: 5.63 	Differnce --> 3.86
# lec = 2.1  	given: 3.69 	Differnce --> 1.59
# lec = 2.33  	given: 2.94 	Differnce --> 0.61
# lec = 1.15  	given: 5.28 	Differnce --> 4.13
# lec = 1.92  	given: 5.00 	Differnce --> 3.08
# lec = 1.63  	given: 6.44 	Differnce --> 4.81
# lec = 1.23  	given: 4.13 	Differnce --> 2.9
# lec = 1.41  	given: 4.75 	Differnce --> 3.34
# lec = 1.07  	given: 2.38 	Differnce --> 1.31
# lec = 1.63  	given: 4.94 	Differnce --> 3.31
# lec = 1.92  	given: 8.06 	Differnce --> 6.14
# lec = 2.33  	given: 5.31 	Differnce --> 2.98
# lec = 1.32  	given: 8.03 	Differnce --> 6.71
# lec = 1.07  	given: 5.94 	Differnce --> 4.87
# lec = 2.1  	given: 6.00 	Differnce --> 3.9
# lec = 1.77  	given: 5.41 	Differnce --> 3.64
# lec = 1.23  	given: 1.81 	Differnce --> 0.58
# lec = 3.02  	given: 8.97 	Differnce --> 5.95
# lec = 1.41  	given: 6.00 	Differnce --> 4.59
# lec = 2.33  	given: 6.72 	Differnce --> 4.39
# lec = 1.63  	given: 8.00 	Differnce --> 6.37
# lec = 1.77  	given: 4.81 	Differnce --> 3.04
# lec = 2.33  	given: 3.88 	Differnce --> 1.55
# lec = 1.52  	given: 5.16 	Differnce --> 3.64
# lec = 1.77  	given: 2.25 	Differnce --> 0.48
# lec = 1.92  	given: 6.44 	Differnce --> 4.52
# lec = 3.02  	given: 8.88 	Differnce --> 5.86
# lec = 1.92  	given: 6.88 	Differnce --> 4.96
# lec = 1.41  	given: 4.94 	Differnce --> 3.53
# lec = 1.15  	given: 2.56 	Differnce --> 1.41
# lec = 1.52  	given: 6.38 	Differnce --> 4.86
# lec = 2.61  	given: 7.81 	Differnce --> 5.2
# lec = 1.63  	given: 1.75 	Differnce --> 0.12
# lec = 2.33  	given: 4.25 	Differnce --> 1.92
# lec = 1.77  	given: 3.88 	Differnce --> 2.11
# lec = 1.77  	given: 2.88 	Differnce --> 1.11
# lec = 2.61  	given: 7.63 	Differnce --> 5.02
# lec = 1.32  	given: 6.48 	Differnce --> 5.16
# lec = 3.71  	given: 8.44 	Differnce --> 4.73
# lec = 1.41  	given: 7.50 	Differnce --> 6.09
# lec = 1.01  	given: 8.59 	Differnce --> 7.58
# lec = 1.52  	given: 6.34 	Differnce --> 4.82
# lec = 1.77  	given: 3.38 	Differnce --> 1.61
# lec = 1.92  	given: 6.00 	Differnce --> 4.08
# lec = 1.32  	given: 3.88 	Differnce --> 2.56
# lec = 1.92  	given: 7.63 	Differnce --> 5.71
# lec = 2.33  	given: 7.78 	Differnce --> 5.45
# lec = 3.71  	given: 9.22 	Differnce --> 5.51
# lec = 1.41  	given: 7.38 	Differnce --> 5.97
# lec = 1.52  	given: 6.09 	Differnce --> 4.57
# lec = 1.15  	given: 8.50 	Differnce --> 7.35
# lec = 2.33  	given: 8.31 	Differnce --> 5.98
# lec = 2.61  	given: 7.13 	Differnce --> 4.52
# lec = 1.52  	given: 5.91 	Differnce --> 4.39
# lec = 1.01  	given: 6.47 	Differnce --> 5.46
# lec = 1.63  	given: 3.38 	Differnce --> 1.75
# lec = 1.63  	given: 3.63 	Differnce --> 2.0
# lec = 0  	given: 7.13 	Differnce --> 7.13
# lec = 3.02  	given: 7.89 	Differnce --> 4.87
# lec = 1.01  	given: 5.97 	Differnce --> 4.96
# lec = 1.77  	given: 7.03 	Differnce --> 5.26
# lec = 1.41  	given: 7.69 	Differnce --> 6.28
# lec = 1.32  	given: 7.47 	Differnce --> 6.15
# lec = 2.61  	given: 6.19 	Differnce --> 3.58
# lec = 1.77  	given: 6.97 	Differnce --> 5.2
# lec = 1.52  	given: 3.56 	Differnce --> 2.04
# lec = 1.63  	given: 7.47 	Differnce --> 5.84
# lec = 3.02  	given: 8.34 	Differnce --> 5.32
# lec = 2.61  	given: 8.70 	Differnce --> 6.09
# lec = 2.33  	given: 7.81 	Differnce --> 5.48
# lec = 1.32  	given: 5.70 	Differnce --> 4.38
# lec = 1.77  	given: 6.22 	Differnce --> 4.45
# lec = 1.52  	given: 6.34 	Differnce --> 4.82
# lec = 1.92  	given: 4.06 	Differnce --> 2.14
# lec = 2.33  	given: 4.47 	Differnce --> 2.14
# lec = 2.61  	given: 5.97 	Differnce --> 3.36
# lec = 1.77  	given: 7.61 	Differnce --> 5.84
# lec = 2.61  	given: 8.36 	Differnce --> 5.75
# lec = 1.32  	given: 7.41 	Differnce --> 6.09
# lec = 2.1  	given: 2.69 	Differnce --> 0.59
# lec = 2.33  	given: 3.94 	Differnce --> 1.61
# lec = 2.33  	given: 7.16 	Differnce --> 4.83
# lec = 1.52  	given: 5.63 	Differnce --> 4.11
# lec = 2.61  	given: 7.53 	Differnce --> 4.92
# lec = 1.92  	given: 8.31 	Differnce --> 6.39
# lec = 3.02  	given: 8.81 	Differnce --> 5.79
# lec = 2.33  	given: 6.25 	Differnce --> 3.92
# lec = 2.61  	given: 8.30 	Differnce --> 5.69
# lec = 2.1  	given: 5.25 	Differnce --> 3.15
# lec = 2.61  	given: 8.53 	Differnce --> 5.92
# lec = 1.07  	given: 7.94 	Differnce --> 6.87
# lec = 1.41  	given: 6.88 	Differnce --> 5.47
# lec = 1.63  	given: 5.94 	Differnce --> 4.31
# lec = 1.77  	given: 4.06 	Differnce --> 2.29
# lec = 1.63  	given: 6.25 	Differnce --> 4.62
# lec = 2.1  	given: 7.72 	Differnce --> 5.62
# lec = 1.15  	given: 6.19 	Differnce --> 5.04
# lec = 1.32  	given: 2.97 	Differnce --> 1.65
# lec = 1.32  	given: 1.94 	Differnce --> 0.62
# lec = 1.77  	given: 3.75 	Differnce --> 1.98
# lec = 2.1  	given: 3.31 	Differnce --> 1.21
# lec = 1.92  	given: 3.69 	Differnce --> 1.77
# lec = 2.1  	given: 7.44 	Differnce --> 5.34
# lec = 1.63  	given: 6.41 	Differnce --> 4.78
# lec = 1.92  	given: 5.44 	Differnce --> 3.52
# lec = 1.41  	given: 6.25 	Differnce --> 4.84
# lec = 1.32  	given: 2.63 	Differnce --> 1.31
# lec = 1.32  	given: 0.88 	Differnce --> 0.44
# lec = 2.61  	given: 3.19 	Differnce --> 0.58
# lec = 1.63  	given: 4.69 	Differnce --> 3.06
# lec = 1.92  	given: 6.75 	Differnce --> 4.83
# lec = 1.92  	given: 5.31 	Differnce --> 3.39
# lec = 1.41  	given: 7.31 	Differnce --> 5.9
# lec = 1.52  	given: 5.75 	Differnce --> 4.23
# lec = 2.33  	given: 3.97 	Differnce --> 1.64
# lec = 1.92  	given: 3.47 	Differnce --> 1.55
# lec = 2.33  	given: 3.63 	Differnce --> 1.3
# lec = 1.92  	given: 5.56 	Differnce --> 3.64
# lec = 3.02  	given: 7.83 	Differnce --> 4.81
# lec = 1.92  	given: 3.88 	Differnce --> 1.96
# lec = 1.52  	given: 5.31 	Differnce --> 3.79
# lec = 1.15  	given: 6.81 	Differnce --> 5.66
# lec = 2.61  	given: 7.59 	Differnce --> 4.98
# lec = 1.77  	given: 7.19 	Differnce --> 5.42
# lec = 1.92  	given: 4.38 	Differnce --> 2.46
# lec = 2.1  	given: 6.53 	Differnce --> 4.43
# lec = 1.77  	given: 6.19 	Differnce --> 4.42
# lec = 1.77  	given: 7.69 	Differnce --> 5.92
# lec = 1.77  	given: 6.31 	Differnce --> 4.54
# lec = 2.1  	given: 6.03 	Differnce --> 3.93
# lec = 1.07  	given: 8.34 	Differnce --> 7.27
# lec = 1.52  	given: 6.25 	Differnce --> 4.73
# lec = 1.41  	given: 6.34 	Differnce --> 4.93
# lec = 1.41  	given: 3.78 	Differnce --> 2.37

# %% [markdown]
# ### Save result in a list

# %%
lec_result = sim_res_list(lec)

# %% [markdown]
# ## Indici di Correlazione

# %% [markdown]
# This module contains the correlation indices implementations. Alternatively one could you use scypy implementation

# %%
def pearson_index(x, y):
    '''
    Implementation of the Pearson index.
    Args:
         x: golden value
         y: similarity list
    Returns:
        Pearson correlation index = [Covariance / (Standard deviation of x * Standard deviation of y)]
    '''
    mu_x = np.mean(x)
    mu_y = np.mean(y)
    
    # and the standard deviation of both
    std_dev_x = np.std(x)
    std_dev_y = np.std(y)

    # subtract mean from each element of x
    modified__x = [elem - mu_x for elem in x] 
    modified__y = [elem - mu_y for elem in y]
    
    num = np.mean(np.multiply(modified__x, modified__y)) # Covariance
    numeric = std_dev_x * std_dev_y

    return num / numeric

def pearson_index_scipy(x, y):
    '''
    Implementation of the Pearson index using scipy
    Args:
         x: golden value
         y: similarity list
    Returns:
        Pearson correlation index = [Covariance / (Standard deviation of x * Standard deviation of y)]
    '''
    return stats.pearsonr(x, y)[0]


def pearson_index_np(x, y):
    '''
    Implementation of the Pearson index using numpy
    Args:
         x: golden value
         y: similarity list
    Returns:
        Pearson correlation index = [Covariance / (Standard deviation of x * Standard deviation of y)]
    '''
    mu_x = np.mean(x)
    mu_y = np.mean(y)
    
    # and the standard deviation of both
    std_dev_x = np.std(x)
    std_dev_y = np.std(y)
    
    numeric = std_dev_x * std_dev_y

    num = np.cov(x, y)[0][1] # Covariance    

    return num / numeric

def spearman_index_scipy(x, y):
    '''
    Implementation of the Spearman index using scipy
    '''
    return stats.spearmanr(x, y)[0]
    

def spearman_index(x, y):
    '''
    Implementation of the Spearman index.
    Args:
        x: golden value
        y: similarity list
    Returns:
         Spearman correlation index
    '''
    rank__x = define_rank(x)
    rank__y = define_rank(y)

    return pearson_index(rank__x, rank__y)


def define_rank(vector):
    '''
    Args:
        vector: numeric vector
    Returns:
        ranks list, sorted as the input order
    '''
    x_couple = [(vector[i], i) for i in range(len(vector))]
    x_couple_sorted = sorted(x_couple, key=lambda x: x[0])

    return [y for (x, y) in x_couple_sorted]

# %% [markdown]
# ## Print corelation index result - scipy

# %%
g_VALUES = [item[2] for item in VALUES] # golden value, the value we want to compare with the similarity list
golden = []
for el in g_VALUES:
    golden.append(float(el))
    
# List of similarity functions to be used in the experiment
sim_algo_list = [my_wu_pal_sim, sim_path, lec]

algo_result = []
i = 0

for algo in sim_algo_list:
    algo_result.append(sim_res_list(algo))

for sim_algo in algo_result:
    print("Pearson index for ", sim_algo_list[i].__name__, "is: ", pearson_index_scipy(golden, sim_algo))
    print("Spearman index for ", sim_algo_list[i].__name__, "is: ",  spearman_index_scipy(golden, sim_algo), "\n")
    i += 1
# Out:
# Pearson index for  my_wu_pal_sim is:  0.28723889591339413
# Spearman index for  my_wu_pal_sim is:  0.3362876896519317
#
# Pearson index for  sim_path is:  0.1641193890897277
# Spearman index for  sim_path is:  0.2883010732370922
#
# Pearson index for  lec is:  0.3127965610951786
# Spearman index for  lec is:  0.2883010732370922

# %% [markdown]
# ### Print corelation index results - Mio

# %%
g_VALUES = [item[2] for item in VALUES] # golden value, the value we want to compare with the similarity list
golden = []
for el in g_VALUES:
    golden.append(float(el))
    
# List of similarity functions to be used in the experiment
sim_algo_list = [my_wu_pal_sim, sim_path, lec]

algo_result = []
i = 0

for algo in sim_algo_list:
    algo_result.append(sim_res_list(algo))

for sim_algo in algo_result:
    print("Pearson index for ", sim_algo_list[i].__name__, "is: ", pearson_index(golden, sim_algo))
    print("Spearman index for ", sim_algo_list[i].__name__, "is: ",  spearman_index(golden, sim_algo), "\n")
    i += 1
# Out:
# Pearson index for  my_wu_pal_sim is:  0.2872388959133944
# Spearman index for  my_wu_pal_sim is:  0.0734025871137553
#
# Pearson index for  sim_path is:  0.16411938908972756
# Spearman index for  sim_path is:  0.007227015194437291
#
# Pearson index for  lec is:  0.31279656109517906
# Spearman index for  lec is:  0.007227015194437291
